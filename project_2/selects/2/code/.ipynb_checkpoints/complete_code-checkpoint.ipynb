# %% [markdown]
# # Project 2: Ames Housing Data and Kaggle Challenge

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Property prices are often subject to fluctuations due to a plethora of reasons. Understanding the underlying contributions of various factors that shape property pricing would be highly insightful. Therefore, the aim of this project is to predict house prices in using **regression models.** Specifically, the housing data of Ames,Iowa would be used for the scope of the project.
#
# In this project, I attempted to train an as accurate a model as possible for predicting house prices in Ames, using regression techniques, feature engineering, feature selection, and regularization.

# %% [markdown]
# ## Why is this important?

# %% [markdown]
# The data set used contains information from the Ames Assessor’s Office used in computing assessed values for individual residential properties sold in Ames, IA from 2006 to 2010. Understanding the relationship between the variables recorded and the sale price would be pivotal in isolating key variables that contribute to sale price. While the findings may be inconclusive, they may be used to inform future decisions regarding data collection and house pricing related decisions.
#
# For example, given further enhancements, the Ames Assessor's Office would be able to use the model to assess the value of housing in Ames, and property agents may be able to use the model as a tool to validate the fairness of the pricing of the property.

# %% [markdown]
# ## Success evaluation

# %% [markdown]
# The success of this project would be evaluated by obtaining the best score for the regression model trained. Specifically, the Root Mean Squared Error (RMSE) of the predicted Sale Price versus actual Sale Price would be used as the scoring metric. The lower the RMSE, the better the model. The dataset used for prediction would be the withheld test set available on Kaggle.

# %%
#Import libraries for use

import numpy as np
import pandas as pd
import patsy

from sklearn.linear_model import Ridge, Lasso, ElasticNet, LinearRegression, RidgeCV, LassoCV, ElasticNetCV
from sklearn.model_selection import cross_val_score

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %% [markdown]
# ## Exploratory Data Analysis

# %%
train = pd.read_csv("../datasets/train.csv")

# %%
#The dataset has 2051 properties, and 81 variables(inclusive of target variable, SalePrice)
train.shape
# Out:
# (2051, 81)

# %%
#Get a sense of the values of the dataset
pd.set_option('max_columns',82)
train.head()
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0       IR1          Lvl    AllPub    CulDSac        Gtl       Sawyer
# 1       IR1          Lvl    AllPub    CulDSac        Gtl      SawyerW
# 2       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 3       Reg          Lvl    AllPub     Inside        Gtl       Timber
# 4       IR1          Lvl    AllPub     Inside        Gtl      SawyerW
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 0        RRAe        Norm      1Fam      2Story             6             8
# 1        Norm        Norm      1Fam      2Story             7             5
# 2        Norm        Norm      1Fam      1Story             5             7
# 3        Norm        Norm      1Fam      2Story             5             5
# 4        Norm        Norm      1Fam      1.5Fin             6             8
#
#    Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st Exterior 2nd  \
# 0        1976            2005      Gable   CompShg      HdBoard      Plywood
# 1        1996            1997      Gable   CompShg      VinylSd      VinylSd
# 2        1953            2007      Gable   CompShg      VinylSd      VinylSd
# 3        2006            2007      Gable   CompShg      VinylSd      VinylSd
# 4        1900            1993      Gable   CompShg      Wd Sdng      Plywood
#
#   Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation Bsmt Qual  \
# 0      BrkFace         289.0         Gd         TA     CBlock        TA
# 1      BrkFace         132.0         Gd         TA      PConc        Gd
# 2         None           0.0         TA         Gd     CBlock        TA
# 3         None           0.0         TA         TA      PConc        Gd
# 4         None           0.0         TA         TA      PConc        Fa
#
#   Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1 BsmtFin Type 2  \
# 0        TA            No            GLQ         533.0            Unf
# 1        TA            No            GLQ         637.0            Unf
# 2        TA            No            GLQ         731.0            Unf
# 3        TA            No            Unf           0.0            Unf
# 4        Gd            No            Unf           0.0            Unf
#
#    BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF Heating Heating QC Central Air  \
# 0           0.0        192.0          725.0    GasA         Ex           Y
# 1           0.0        276.0          913.0    GasA         Ex           Y
# 2           0.0        326.0         1057.0    GasA         TA           Y
# 3           0.0        384.0          384.0    GasA         Gd           Y
# 4           0.0        676.0          676.0    GasA         TA           Y
#
#   Electrical  1st Flr SF  2nd Flr SF  Low Qual Fin SF  Gr Liv Area  \
# 0      SBrkr         725         754                0         1479
# 1      SBrkr         913        1209                0         2122
# 2      SBrkr        1057           0                0         1057
# 3      SBrkr         744         700                0         1444
# 4      SBrkr         831         614                0         1445
#
#    Bsmt Full Bath  Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  \
# 0             0.0             0.0          2          1              3
# 1             1.0             0.0          2          1              4
# 2             1.0             0.0          1          0              3
# 3             0.0             0.0          2          1              3
# 4             0.0             0.0          2          0              3
#
#    Kitchen AbvGr Kitchen Qual  TotRms AbvGrd Functional  Fireplaces  \
# 0              1           Gd              6        Typ           0
# 1              1           Gd              8        Typ           1
# 2              1           Gd              5        Typ           0
# 3              1           TA              7        Typ           0
# 4              1           TA              6        Typ           0
#
#   Fireplace Qu Garage Type  Garage Yr Blt Garage Finish  Garage Cars  \
# 0          NaN      Attchd         1976.0           RFn          2.0
# 1           TA      Attchd         1997.0           RFn          2.0
# 2          NaN      Detchd         1953.0           Unf          1.0
# 3          NaN     BuiltIn         2007.0           Fin          2.0
# 4          NaN      Detchd         1957.0           Unf          2.0
#
#    Garage Area Garage Qual Garage Cond Paved Drive  Wood Deck SF  \
# 0        475.0          TA          TA           Y             0
# 1        559.0          TA          TA           Y             0
# 2        246.0          TA          TA           Y             0
# 3        400.0          TA          TA           Y           100
# 4        484.0          TA          TA           N             0
#
#    Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  Pool Area Pool QC  \
# 0             44               0           0             0          0     NaN
# 1             74               0           0             0          0     NaN
# 2             52               0           0             0          0     NaN
# 3              0               0           0             0          0     NaN
# 4             59               0           0             0          0     NaN
#
#   Fence Misc Feature  Misc Val  Mo Sold  Yr Sold Sale Type  SalePrice
# 0   NaN          NaN         0        3     2010       WD      130500
# 1   NaN          NaN         0        4     2009       WD      220000
# 2   NaN          NaN         0        1     2010       WD      109000
# 3   NaN          NaN         0        4     2010       WD      174000
# 4   NaN          NaN         0        3     2010       WD      138500

# %%
#Check non-null values in the dataset, as well as the datatypes -->train.info()
#The data description states that: "The data has 82 columns which include 
#23 nominal, 23 ordinal, 14 discrete, and 20 continuous variables (and 2 additional observation identifiers)."
#I assigned the variable type from the data description on top what was provided

# %%
train.head()
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0       IR1          Lvl    AllPub    CulDSac        Gtl       Sawyer
# 1       IR1          Lvl    AllPub    CulDSac        Gtl      SawyerW
# 2       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 3       Reg          Lvl    AllPub     Inside        Gtl       Timber
# 4       IR1          Lvl    AllPub     Inside        Gtl      SawyerW
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 0        RRAe        Norm      1Fam      2Story             6             8
# 1        Norm        Norm      1Fam      2Story             7             5
# 2        Norm        Norm      1Fam      1Story             5             7
# 3        Norm        Norm      1Fam      2Story             5             5
# 4        Norm        Norm      1Fam      1.5Fin             6             8
#
#    Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st Exterior 2nd  \
# 0        1976            2005      Gable   CompShg      HdBoard      Plywood
# 1        1996            1997      Gable   CompShg      VinylSd      VinylSd
# 2        1953            2007      Gable   CompShg      VinylSd      VinylSd
# 3        2006            2007      Gable   CompShg      VinylSd      VinylSd
# 4        1900            1993      Gable   CompShg      Wd Sdng      Plywood
#
#   Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation Bsmt Qual  \
# 0      BrkFace         289.0         Gd         TA     CBlock        TA
# 1      BrkFace         132.0         Gd         TA      PConc        Gd
# 2         None           0.0         TA         Gd     CBlock        TA
# 3         None           0.0         TA         TA      PConc        Gd
# 4         None           0.0         TA         TA      PConc        Fa
#
#   Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1 BsmtFin Type 2  \
# 0        TA            No            GLQ         533.0            Unf
# 1        TA            No            GLQ         637.0            Unf
# 2        TA            No            GLQ         731.0            Unf
# 3        TA            No            Unf           0.0            Unf
# 4        Gd            No            Unf           0.0            Unf
#
#    BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF Heating Heating QC Central Air  \
# 0           0.0        192.0          725.0    GasA         Ex           Y
# 1           0.0        276.0          913.0    GasA         Ex           Y
# 2           0.0        326.0         1057.0    GasA         TA           Y
# 3           0.0        384.0          384.0    GasA         Gd           Y
# 4           0.0        676.0          676.0    GasA         TA           Y
#
#   Electrical  1st Flr SF  2nd Flr SF  Low Qual Fin SF  Gr Liv Area  \
# 0      SBrkr         725         754                0         1479
# 1      SBrkr         913        1209                0         2122
# 2      SBrkr        1057           0                0         1057
# 3      SBrkr         744         700                0         1444
# 4      SBrkr         831         614                0         1445
#
#    Bsmt Full Bath  Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  \
# 0             0.0             0.0          2          1              3
# 1             1.0             0.0          2          1              4
# 2             1.0             0.0          1          0              3
# 3             0.0             0.0          2          1              3
# 4             0.0             0.0          2          0              3
#
#    Kitchen AbvGr Kitchen Qual  TotRms AbvGrd Functional  Fireplaces  \
# 0              1           Gd              6        Typ           0
# 1              1           Gd              8        Typ           1
# 2              1           Gd              5        Typ           0
# 3              1           TA              7        Typ           0
# 4              1           TA              6        Typ           0
#
#   Fireplace Qu Garage Type  Garage Yr Blt Garage Finish  Garage Cars  \
# 0          NaN      Attchd         1976.0           RFn          2.0
# 1           TA      Attchd         1997.0           RFn          2.0
# 2          NaN      Detchd         1953.0           Unf          1.0
# 3          NaN     BuiltIn         2007.0           Fin          2.0
# 4          NaN      Detchd         1957.0           Unf          2.0
#
#    Garage Area Garage Qual Garage Cond Paved Drive  Wood Deck SF  \
# 0        475.0          TA          TA           Y             0
# 1        559.0          TA          TA           Y             0
# 2        246.0          TA          TA           Y             0
# 3        400.0          TA          TA           Y           100
# 4        484.0          TA          TA           N             0
#
#    Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  Pool Area Pool QC  \
# 0             44               0           0             0          0     NaN
# 1             74               0           0             0          0     NaN
# 2             52               0           0             0          0     NaN
# 3              0               0           0             0          0     NaN
# 4             59               0           0             0          0     NaN
#
#   Fence Misc Feature  Misc Val  Mo Sold  Yr Sold Sale Type  SalePrice
# 0   NaN          NaN         0        3     2010       WD      130500
# 1   NaN          NaN         0        4     2009       WD      220000
# 2   NaN          NaN         0        1     2010       WD      109000
# 3   NaN          NaN         0        4     2010       WD      174000
# 4   NaN          NaN         0        3     2010       WD      138500

# %% [raw]
# #   Column           Non-Null 	Count 	Dtype  Variable type
# ---  ------           --------------  -----     --------
#  0   Id               2051 non-null   int64
#  1   PID              2051 non-null   int64
#  2   MS SubClass      2051 non-null   int64  	Nominal
#  3   MS Zoning        2051 non-null   object 	Nominal
#  4   Lot Frontage     1721 non-null   float64	Continuous
#  5   Lot Area         2051 non-null   int64  	Continuous
#  6   Street           2051 non-null   object 	Nominal
#  7   Alley            140 non-null    object 	Nominal
#  8   Lot Shape        2051 non-null   object 	Ordinal
#  9   Land Contour     2051 non-null   object 	Nominal
#  10  Utilities        2051 non-null   object 	Ordinal
#  11  Lot Config       2051 non-null   object 	Nominal
#  12  Land Slope       2051 non-null   object 	Ordinal
#  13  Neighborhood     2051 non-null   object 	Nominal
#  14  Condition 1      2051 non-null   object 	Nominal
#  15  Condition 2      2051 non-null   object 	Nominal
#  16  Bldg Type        2051 non-null   object 	Nominal
#  17  House Style      2051 non-null   object 	Nominal
#  18  Overall Qual     2051 non-null   int64  	Ordinal
#  19  Overall Cond     2051 non-null   int64  	Ordinal
#  20  Year Built       2051 non-null   int64  	Discrete
#  21  Year Remod/Add   2051 non-null   int64  	Discrete
#  22  Roof Style       2051 non-null   object 	Nominal
#  23  Roof Matl        2051 non-null   object 	Nominal
#  24  Exterior 1st     2051 non-null   object 	Nominal
#  25  Exterior 2nd     2051 non-null   object 	Nominal
#  26  Mas Vnr Type     2029 non-null   object 	Nominal
#  27  Mas Vnr Area     2029 non-null   float64	Continuous
#  28  Exter Qual       2051 non-null   object 	Ordinal
#  29  Exter Cond       2051 non-null   object 	Ordinal
#  30  Foundation       2051 non-null   object 	Nominal
#  31  Bsmt Qual        1996 non-null   object 	Ordinal
#  32  Bsmt Cond        1996 non-null   object 	Ordinal
#  33  Bsmt Exposure    1993 non-null   object 	Ordinal
#  34  BsmtFin Type 1   1996 non-null   object 	Ordinal
#  35  BsmtFin SF 1     2050 non-null   float64	Continuous
#  36  BsmtFin Type 2   1995 non-null   object 	Ordinal
#  37  BsmtFin SF 2     2050 non-null   float64	Continuous
#  38  Bsmt Unf SF      2050 non-null   float64	Continuous
#  39  Total Bsmt SF    2050 non-null   float64	Continuous
#  40  Heating          2051 non-null   object 	Nominal
#  41  Heating QC       2051 non-null   object 	Ordinal
#  42  Central Air      2051 non-null   object 	Nominal
#  43  Electrical       2051 non-null   object 	Ordinal
#  44  1st Flr SF       2051 non-null   int64  	Continuous
#  45  2nd Flr SF       2051 non-null   int64  	Continuous
#  46  Low Qual Fin SF  2051 non-null   int64  	Continuous
#  47  Gr Liv Area      2051 non-null   int64  	Continuous
#  48  Bsmt Full Bath   2049 non-null   float64	Discrete
#  49  Bsmt Half Bath   2049 non-null   float64	Discrete
#  50  Full Bath        2051 non-null   int64  	Discrete
#  51  Half Bath        2051 non-null   int64  	Discrete
#  52  Bedroom AbvGr    2051 non-null   int64  	Discrete
#  53  Kitchen AbvGr    2051 non-null   int64  	Discrete
#  54  Kitchen Qual     2051 non-null   object 	Ordinal
#  55  TotRms AbvGrd    2051 non-null   int64  	Discrete
#  56  Functional       2051 non-null   object 	Ordinal
#  57  Fireplaces       2051 non-null   int64  	Discrete
#  58  Fireplace Qu     1051 non-null   object 	Ordinal
#  59  Garage Type      1938 non-null   object 	Nominal
#  60  Garage Yr Blt    1937 non-null   float64	Discrete
#  61  Garage Finish    1937 non-null   object 	Ordinal
#  62  Garage Cars      2050 non-null   float64	Discrete
#  63  Garage Area      2050 non-null   float64	Continuous
#  64  Garage Qual      1937 non-null   object 	Ordinal
#  65  Garage Cond      1937 non-null   object 	Ordinal
#  66  Paved Drive      2051 non-null   object 	Ordinal
#  67  Wood Deck SF     2051 non-null   int64  	Continuous
#  68  Open Porch SF    2051 non-null   int64  	Continuous
#  69  Enclosed Porch   2051 non-null   int64  	Continuous
#  70  3Ssn Porch       2051 non-null   int64  	Continuous
#  71  Screen Porch     2051 non-null   int64  	Continuous
#  72  Pool Area        2051 non-null   int64  	Continuous
#  73  Pool QC          9 non-null      object 	Ordinal
#  74  Fence            400 non-null    object 	Ordinal
#  75  Misc Feature     65 non-null     object 	Nominal
#  76  Misc Val         2051 non-null   int64  	Continuous
#  77  Mo Sold          2051 non-null   int64  	Discrete
#  78  Yr Sold          2051 non-null   int64  	Discrete
#  79  Sale Type        2051 non-null   object 	Nominal
#  80  SalePrice        2051 non-null   int64 	Continuous

# %% [markdown]
# There are 4 main types of data that will be handled:
# - Nominal: Unordered categorical variables. Will have to create numerical dummies ( Yes:1 , No:0 ) in order to include in the model
# - Ordinal: Ordered categorical variables. Will have to create ordered numerical dummies that reflect the magnitude of the response (eg. -2 for bad, 0 for neutral, 2 for good)
# - Discrete: Numerical integers that are in set intervals
# - Continuous: Numerical integers that can be found in a range

# %%
train.shape
# Out:
# (2051, 81)

# %% [markdown]
# # Processing nominal variables

# %% [markdown]
# The nominal variables can be split into two main types:
# - Those without null values:

# %% [raw]
# #   Column           Non-Null 	Count 	Dtype  Variable type
# ---  ------           --------------  -----     --------
#  2   MS SubClass      2051 non-null   int64  	Nominal
#  3   MS Zoning        2051 non-null   object 	Nominal
#  6   Street           2051 non-null   object 	Nominal
#  9   Land Contour     2051 non-null   object 	Nominal
#  11  Lot Config       2051 non-null   object 	Nominal
#  13  Neighborhood     2051 non-null   object 	Nominal
#  14  Condition 1      2051 non-null   object 	Nominal
#  15  Condition 2      2051 non-null   object 	Nominal
#  16  Bldg Type        2051 non-null   object 	Nominal
#  17  House Style      2051 non-null   object 	Nominal
#  22  Roof Style       2051 non-null   object 	Nominal
#  23  Roof Matl        2051 non-null   object 	Nominal
#  24  Exterior 1st     2051 non-null   object 	Nominal
#  25  Exterior 2nd     2051 non-null   object 	Nominal
#  30  Foundation       2051 non-null   object 	Nominal
#  40  Heating          2051 non-null   object 	Nominal
#  42  Central Air      2051 non-null   object 	Nominal
#  79  Sale Type        2051 non-null   object 	Nominal

# %% [markdown]
# - Those with null values, which are to be processed:

# %% [raw]
#  7   Alley            140 non-null    object 	Nominal
#  26  Mas Vnr Type     2029 non-null   object 	Nominal
#  59  Garage Type      1938 non-null   object 	Nominal
#  75  Misc Feature     65 non-null     object 	Nominal

# %% [markdown]
# # Masonry Veneer Type data imputation

# %%
#The count of houses with Masonry veneers
#Note that most of the houses do not have one
train['Mas Vnr Type'].value_counts(dropna=False)
# Out:
# None       1218
# BrkFace     630
# Stone       168
# NaN          22
# BrkCmn       13
# Name: Mas Vnr Type, dtype: int64

# %%
#I include 'Mas Vnr Area' in processing even though it is a continuous variable, as I believe them to be  
#highly related: without a Masonry Veneer, you will not have a Masonry Veneer Area
#Note that most of the houses have 0.0 for this variable
train['Mas Vnr Area'].value_counts(dropna=False)
# Out:
# 0.0       1216
# NaN         22
# 120.0       11
# 200.0       10
# 176.0       10
#           ...
# 468.0        1
# 235.0        1
# 362.0        1
# 199.0        1
# 1095.0       1
# Name: Mas Vnr Area, Length: 374, dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
#Impute NaN values with the most frequent value. None for Mas Vnr Type, 0.0 for Mas Vnr Area
imp1 = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
train.loc[:,"Mas Vnr Type":"Mas Vnr Area"] = imp1.fit_transform(train.loc[:,"Mas Vnr Type":"Mas Vnr Area"])

# %% [markdown]
# I decided to impute the missing values for 'Mas Vnr Type' and 'Mas Vnr Area' with the mode. Since most of the other data in other columns exists, I suspect it is unlikely that the missing value stems from a failed data collection. Seeing that most of the houses did not have a Masonry Veneer, I decided to impute the mode on all the missing values.

# %% [markdown]
# # Alley data imputation

# %%
train.Alley.value_counts(dropna=False)
# Out:
# NaN     1911
# Grvl      85
# Pave      55
# Name: Alley, dtype: int64

# %% [markdown]
# As the data description mentions that 3 categories are present: Grvl, Pave, and NA, I suspect that the NaN values were synonymous with the NA value present in the data description, which stands for 'No Alley access'. As such, I will impute all null values with 'NA'.

# %%
#Impute NaN values with the value 'None':'No alley access'
imp2 = SimpleImputer(missing_values=np.nan, fill_value='None', strategy='constant')
train.loc[:,"Alley"] = imp2.fit_transform(train['Alley'].values.reshape(-1,1))

# %%
train.Alley.value_counts()
# Out:
# None    1911
# Grvl      85
# Pave      55
# Name: Alley, dtype: int64

# %% [markdown]
# # Garage Type imputation

# %%
#Check current 'Garage Type' count of each value
train['Garage Type'].value_counts(dropna=False)
# Out:
# Attchd     1213
# Detchd      536
# BuiltIn     132
# NaN         113
# Basment      27
# 2Types       19
# CarPort      11
# Name: Garage Type, dtype: int64

# %% [markdown]
# Similar to the variable 'Alley', the data description clearly mentions that one of the categorical values of 'Garage Type' should be 'NA' which stands for: No Garage. However, since it is not reflected here, I suspect that the NaN values actually refer to NA--No Garage

# %%
#Impute NaN values with the value 'NA':'No Garage'
#I apply imp2 (previously instantiated) to transform 'Garage Type'
train.loc[:,"Garage Type"] = imp2.fit_transform(train['Garage Type'].values.reshape(-1,1))

# %%
#Successful imputed NaN values with 'NA'
train['Garage Type'].value_counts(dropna=False)
# Out:
# Attchd     1213
# Detchd      536
# BuiltIn     132
# None        113
# Basment      27
# 2Types       19
# CarPort      11
# Name: Garage Type, dtype: int64

# %% [markdown]
# # Misc Feature imputation

# %%
#Show the proportion of missing values 
train['Misc Feature'].value_counts(dropna=False)
# Out:
# NaN     1986
# Shed      56
# Gar2       4
# Othr       3
# TenC       1
# Elev       1
# Name: Misc Feature, dtype: int64

# %% [markdown]
# Similar to the variables 'Garage Type' and 'Alley', the data description clearly mentions that one of the categorical values of 'Misc Feature' should be 'NA' which stands for: None. However, since it is not reflected here, I suspect that the NaN values actually refer to NA--None(No misc features).

# %%
#Impute NaN values with the value 'NA':'None'
#I apply imp2 (previously instantiated) to transform 'Misc Feature'
train.loc[:,"Misc Feature"] = imp2.fit_transform(train['Misc Feature'].values.reshape(-1,1))

# %%
#Nan values successfully imputed with 'NA'
train['Misc Feature'].value_counts(dropna=False)
# Out:
# None    1986
# Shed      56
# Gar2       4
# Othr       3
# TenC       1
# Elev       1
# Name: Misc Feature, dtype: int64

# %% [markdown]
# # Processing ordinal variables

# %% [markdown]
# The ordinal variables can be broadly split into two categories:
# - variables without null values

# %%
train['Lot Shape'].isnull().sum()
# Out:
# 0

# %% [raw]
# #    Column           Non-Null Count  Dtype     Variable type
# ---  ------           --------------  -----     --------
#
#  8   Lot Shape        2051 non-null   object 	Ordinal
#  10  Utilities        2051 non-null   object 	Ordinal
#  12  Land Slope       2051 non-null   object 	Ordinal
#  18  Overall Qual     2051 non-null   int64  	Ordinal
#  19  Overall Cond     2051 non-null   int64  	Ordinal
#  28  Exter Qual       2051 non-null   object 	Ordinal
#  29  Exter Cond       2051 non-null   object 	Ordinal
#  41  Heating QC       2051 non-null   object 	Ordinal
#  43  Electrical       2051 non-null   object 	Ordinal
#  54  Kitchen Qual     2051 non-null   object 	Ordinal
#  56  Functional       2051 non-null   object 	Ordinal
#  66  Paved Drive      2051 non-null   object 	Ordinal

# %% [markdown]
# - variables with null values

# %% [raw]
#  31  Bsmt Qual        1996 non-null   object 	Ordinal
#  32  Bsmt Cond        1996 non-null   object 	Ordinal
#  33  Bsmt Exposure    1993 non-null   object 	Ordinal
#  34  BsmtFin Type 1   1996 non-null   object 	Ordinal
#  36  BsmtFin Type 2   1995 non-null   object 	Ordinal
#  58  Fireplace Qu     1051 non-null   object 	Ordinal
#  61  Garage Finish    1937 non-null   object 	Ordinal
#  64  Garage Qual      1937 non-null   object 	Ordinal
#  65  Garage Cond      1937 non-null   object 	Ordinal
#  73  Pool QC          9 non-null      object 	Ordinal
#  74  Fence            400 non-null    object 	Ordinal

# %% [markdown]
# The tricky thing about creating dummy variables for ordinal variables, is that it can be subjective (eg. no basement is worse than a poor basement). As such, these ordered variables will in general be assigned a range of integers [-2,-1,0,1,2] whereby a positive score denotes a more favorable trait, and vice versa for a negative score.
#
# In variables where there appears to be no real negative(or positive) responses, a non-negative(or non-positive) range
# can be used to approximate the relationship of the variable (eg. [0,1,2,3] or [-3,-2,-1,0])
#
# Lastly, in my opinion, the weightage of the extreme ends of the variables can be allocated a higher value. (eg.[-5,-2,0,2,5] instead of [-2,-1,0,1,2])

# %% [markdown]
# # Basement-related imputation of missing data

# %%
#Among the null values in 'Bsmt Exposure', 55 of them are overlaps with 4 other columns
train[train['Bsmt Exposure'].isnull()].loc[:,'Bsmt Qual':'Total Bsmt SF'].isnull().sum()
# Out:
# Bsmt Qual         55
# Bsmt Cond         55
# Bsmt Exposure     58
# BsmtFin Type 1    55
# BsmtFin SF 1       1
# BsmtFin Type 2    55
# BsmtFin SF 2       1
# Bsmt Unf SF        1
# Total Bsmt SF      1
# dtype: int64

# %%
#Confirmation that 55 rows of data are 'No Basement', 3 rows of data has an unaccounted for NaN for Bsmt Exposure
train[train['Bsmt Exposure'].isnull()].loc[:,'Bsmt Qual':'Total Bsmt SF']
# Out:
#      Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1  \
# 12         NaN       NaN           NaN            NaN           0.0
# 93         NaN       NaN           NaN            NaN           0.0
# 114        NaN       NaN           NaN            NaN           0.0
# 146        NaN       NaN           NaN            NaN           0.0
# 183        NaN       NaN           NaN            NaN           0.0
# 240        NaN       NaN           NaN            NaN           0.0
# 249        NaN       NaN           NaN            NaN           0.0
# 256        NaN       NaN           NaN            NaN           0.0
# 390        NaN       NaN           NaN            NaN           0.0
# 437        NaN       NaN           NaN            NaN           0.0
# 485        NaN       NaN           NaN            NaN           0.0
# 499        NaN       NaN           NaN            NaN           0.0
# 514        NaN       NaN           NaN            NaN           0.0
# 580        NaN       NaN           NaN            NaN           0.0
# 581        NaN       NaN           NaN            NaN           0.0
# 616        NaN       NaN           NaN            NaN           0.0
# 635        NaN       NaN           NaN            NaN           0.0
# 642        NaN       NaN           NaN            NaN           0.0
# 696        NaN       NaN           NaN            NaN           0.0
# 700        NaN       NaN           NaN            NaN           0.0
# 737        NaN       NaN           NaN            NaN           0.0
# 772        NaN       NaN           NaN            NaN           0.0
# 790        NaN       NaN           NaN            NaN           0.0
# 794        NaN       NaN           NaN            NaN           0.0
# 924        NaN       NaN           NaN            NaN           0.0
# 933        NaN       NaN           NaN            NaN           0.0
# 954        NaN       NaN           NaN            NaN           0.0
# 1007       NaN       NaN           NaN            NaN           0.0
# 1022       NaN       NaN           NaN            NaN           0.0
# 1049       NaN       NaN           NaN            NaN           0.0
# 1089       NaN       NaN           NaN            NaN           0.0
# 1098       NaN       NaN           NaN            NaN           0.0
# 1125       NaN       NaN           NaN            NaN           0.0
# 1157       NaN       NaN           NaN            NaN           0.0
# 1211       NaN       NaN           NaN            NaN           0.0
# 1222       NaN       NaN           NaN            NaN           0.0
# 1252       NaN       NaN           NaN            NaN           0.0
# 1256       NaN       NaN           NaN            NaN           0.0
# 1270       NaN       NaN           NaN            NaN           0.0
# 1327       NaN       NaN           NaN            NaN           NaN
# 1331       NaN       NaN           NaN            NaN           0.0
# 1377       NaN       NaN           NaN            NaN           0.0
# 1387       NaN       NaN           NaN            NaN           0.0
# 1428       NaN       NaN           NaN            NaN           0.0
# 1456        Gd        TA           NaN            Unf           0.0
# 1481       NaN       NaN           NaN            NaN           0.0
# 1547        Gd        TA           NaN            Unf           0.0
# 1594       NaN       NaN           NaN            NaN           0.0
# 1620       NaN       NaN           NaN            NaN           0.0
# 1681       NaN       NaN           NaN            NaN           0.0
# 1684       NaN       NaN           NaN            NaN           0.0
# 1686       NaN       NaN           NaN            NaN           0.0
# 1859       NaN       NaN           NaN            NaN           0.0
# 1875       NaN       NaN           NaN            NaN           0.0
# 1889       NaN       NaN           NaN            NaN           0.0
# 1933       NaN       NaN           NaN            NaN           0.0
# 1997        Gd        TA           NaN            Unf           0.0
# 2010       NaN       NaN           NaN            NaN           0.0
#
#      BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF
# 12              NaN           0.0          0.0            0.0
# 93              NaN           0.0          0.0            0.0
# 114             NaN           0.0          0.0            0.0
# 146             NaN           0.0          0.0            0.0
# 183             NaN           0.0          0.0            0.0
# 240             NaN           0.0          0.0            0.0
# 249             NaN           0.0          0.0            0.0
# 256             NaN           0.0          0.0            0.0
# 390             NaN           0.0          0.0            0.0
# 437             NaN           0.0          0.0            0.0
# 485             NaN           0.0          0.0            0.0
# 499             NaN           0.0          0.0            0.0
# 514             NaN           0.0          0.0            0.0
# 580             NaN           0.0          0.0            0.0
# 581             NaN           0.0          0.0            0.0
# 616             NaN           0.0          0.0            0.0
# 635             NaN           0.0          0.0            0.0
# 642             NaN           0.0          0.0            0.0
# 696             NaN           0.0          0.0            0.0
# 700             NaN           0.0          0.0            0.0
# 737             NaN           0.0          0.0            0.0
# 772             NaN           0.0          0.0            0.0
# 790             NaN           0.0          0.0            0.0
# 794             NaN           0.0          0.0            0.0
# 924             NaN           0.0          0.0            0.0
# 933             NaN           0.0          0.0            0.0
# 954             NaN           0.0          0.0            0.0
# 1007            NaN           0.0          0.0            0.0
# 1022            NaN           0.0          0.0            0.0
# 1049            NaN           0.0          0.0            0.0
# 1089            NaN           0.0          0.0            0.0
# 1098            NaN           0.0          0.0            0.0
# 1125            NaN           0.0          0.0            0.0
# 1157            NaN           0.0          0.0            0.0
# 1211            NaN           0.0          0.0            0.0
# 1222            NaN           0.0          0.0            0.0
# 1252            NaN           0.0          0.0            0.0
# 1256            NaN           0.0          0.0            0.0
# 1270            NaN           0.0          0.0            0.0
# 1327            NaN           NaN          NaN            NaN
# 1331            NaN           0.0          0.0            0.0
# 1377            NaN           0.0          0.0            0.0
# 1387            NaN           0.0          0.0            0.0
# 1428            NaN           0.0          0.0            0.0
# 1456            Unf           0.0        725.0          725.0
# 1481            NaN           0.0          0.0            0.0
# 1547            Unf           0.0       1595.0         1595.0
# 1594            NaN           0.0          0.0            0.0
# 1620            NaN           0.0          0.0            0.0
# 1681            NaN           0.0          0.0            0.0
# 1684            NaN           0.0          0.0            0.0
# 1686            NaN           0.0          0.0            0.0
# 1859            NaN           0.0          0.0            0.0
# 1875            NaN           0.0          0.0            0.0
# 1889            NaN           0.0          0.0            0.0
# 1933            NaN           0.0          0.0            0.0
# 1997            Unf           0.0        936.0          936.0
# 2010            NaN           0.0          0.0            0.0

# %%
#A look at the 3 rows that contain missing value for Bsmt Exposure.
train.iloc[[1456,1547,1997],:]
# Out:
#         Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 1456  1797  528458090           60        FV          81.0     10411   Pave
# 1547    67  528445060           20        RL          73.0      8987   Pave
# 1997  2780  907194130           60        RL          65.0     14006   Pave
#
#      Alley Lot Shape Land Contour Utilities Lot Config Land Slope  \
# 1456  None       Reg          Lvl    AllPub     Corner        Gtl
# 1547  None       Reg          Lvl    AllPub     Inside        Gtl
# 1997  None       IR1          Lvl    AllPub     Inside        Gtl
#
#      Neighborhood Condition 1 Condition 2 Bldg Type House Style  Overall Qual  \
# 1456      Somerst        Norm        Norm      1Fam      2Story             5
# 1547      Somerst        Norm        Norm      1Fam      1Story             8
# 1997      CollgCr        Norm        Norm      1Fam      2Story             7
#
#       Overall Cond  Year Built  Year Remod/Add Roof Style Roof Matl  \
# 1456             5        2007            2007      Gable   CompShg
# 1547             5        2005            2006      Gable   CompShg
# 1997             5        2002            2002      Gable   CompShg
#
#      Exterior 1st Exterior 2nd Mas Vnr Type  Mas Vnr Area Exter Qual  \
# 1456      VinylSd      VinylSd         None           0.0         Gd
# 1547      VinylSd      VinylSd      BrkFace         226.0         Gd
# 1997      VinylSd      VinylSd      BrkFace         144.0         Gd
#
#      Exter Cond Foundation Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1  \
# 1456         TA     CBlock        Gd        TA           NaN            Unf
# 1547         TA      PConc        Gd        TA           NaN            Unf
# 1997         TA      PConc        Gd        TA           NaN            Unf
#
#       BsmtFin SF 1 BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF  \
# 1456           0.0            Unf           0.0        725.0          725.0
# 1547           0.0            Unf           0.0       1595.0         1595.0
# 1997           0.0            Unf           0.0        936.0          936.0
#
#      Heating Heating QC Central Air Electrical  1st Flr SF  2nd Flr SF  \
# 1456    GasA         Ex           Y      SBrkr         725         863
# 1547    GasA         Ex           Y      SBrkr        1595           0
# 1997    GasA         Ex           Y      SBrkr         936         840
#
#       Low Qual Fin SF  Gr Liv Area  Bsmt Full Bath  Bsmt Half Bath  Full Bath  \
# 1456                0         1588             0.0             0.0          3
# 1547                0         1595             0.0             0.0          2
# 1997                0         1776             0.0             0.0          2
#
#       Half Bath  Bedroom AbvGr  Kitchen AbvGr Kitchen Qual  TotRms AbvGrd  \
# 1456          0              3              1           Gd              8
# 1547          0              2              1           Gd              6
# 1997          1              3              1           Gd              7
#
#      Functional  Fireplaces Fireplace Qu Garage Type  Garage Yr Blt  \
# 1456        Typ           0          NaN      Attchd         2007.0
# 1547        Typ           1           Gd      Attchd         2005.0
# 1997        Typ           1           TA      Attchd         2002.0
#
#      Garage Finish  Garage Cars  Garage Area Garage Qual Garage Cond  \
# 1456           Unf          2.0        561.0          TA          TA
# 1547           RFn          3.0        880.0          TA          TA
# 1997           RFn          2.0        474.0          TA          TA
#
#      Paved Drive  Wood Deck SF  Open Porch SF  Enclosed Porch  3Ssn Porch  \
# 1456           Y             0              0               0           0
# 1547           Y           144              0               0           0
# 1997           Y           144             96               0           0
#
#       Screen Porch  Pool Area Pool QC Fence Misc Feature  Misc Val  Mo Sold  \
# 1456             0          0     NaN   NaN         None         0        7
# 1547             0          0     NaN   NaN         None         0        5
# 1997             0          0     NaN   NaN         None         0        2
#
#       Yr Sold Sale Type  SalePrice
# 1456     2007       New     212109
# 1547     2010       WD      221500
# 1997     2006       WD      192500

# %% [markdown]
# Looking at the data, it appears that most of the columns have similar missing values for 55 rows. Referring to the Data Description, it reveals that a value 'NA': No Basement was not included in our analysis. As such, I suspect that missing values are actually indicative of a property with no basement for these 55 rows. A simple imputation of NA: No Basement to these missing values should suffice.
#
# However, 'Bsmt Exposure' stands out, having yet another 3 rows (index 1456,1547,1997) with missing values after accounting for the 55 no basement values. I would therefore have to decide between removing these data, or imputing values to them.
#
# Taking into consideration to keep imputation to the minimum where possible, and considering the small size of the dataset, I decide to drop these 3 rows from the dataset.

# %%
#I drop the 3 unaccounted for missing values from Bsmt Exposure
train.drop(index=[1456,1547,1997],inplace=True)

# %% [markdown]
# Next, we deal with the 1 unaccounted missing value from BsmtFin Type 2

# %%
train['BsmtFin Type 2'].value_counts(dropna=False)
# Out:
# Unf    1746
# Rec      80
# LwQ      60
# NaN      56
# BLQ      48
# ALQ      35
# GLQ      23
# Name: BsmtFin Type 2, dtype: int64

# %%
#BsmtFin Type 2 has 1 additional Nan value compared to the baseline of 55
train[train['BsmtFin Type 2'].isnull()].loc[:,'Bsmt Qual':'Total Bsmt SF']
# Out:
#      Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1  \
# 12         NaN       NaN           NaN            NaN           0.0
# 93         NaN       NaN           NaN            NaN           0.0
# 114        NaN       NaN           NaN            NaN           0.0
# 146        NaN       NaN           NaN            NaN           0.0
# 183        NaN       NaN           NaN            NaN           0.0
# 240        NaN       NaN           NaN            NaN           0.0
# 249        NaN       NaN           NaN            NaN           0.0
# 256        NaN       NaN           NaN            NaN           0.0
# 390        NaN       NaN           NaN            NaN           0.0
# 437        NaN       NaN           NaN            NaN           0.0
# 485        NaN       NaN           NaN            NaN           0.0
# 499        NaN       NaN           NaN            NaN           0.0
# 514        NaN       NaN           NaN            NaN           0.0
# 580        NaN       NaN           NaN            NaN           0.0
# 581        NaN       NaN           NaN            NaN           0.0
# 616        NaN       NaN           NaN            NaN           0.0
# 635        NaN       NaN           NaN            NaN           0.0
# 642        NaN       NaN           NaN            NaN           0.0
# 696        NaN       NaN           NaN            NaN           0.0
# 700        NaN       NaN           NaN            NaN           0.0
# 737        NaN       NaN           NaN            NaN           0.0
# 772        NaN       NaN           NaN            NaN           0.0
# 790        NaN       NaN           NaN            NaN           0.0
# 794        NaN       NaN           NaN            NaN           0.0
# 924        NaN       NaN           NaN            NaN           0.0
# 933        NaN       NaN           NaN            NaN           0.0
# 954        NaN       NaN           NaN            NaN           0.0
# 1007       NaN       NaN           NaN            NaN           0.0
# 1022       NaN       NaN           NaN            NaN           0.0
# 1049       NaN       NaN           NaN            NaN           0.0
# 1089       NaN       NaN           NaN            NaN           0.0
# 1098       NaN       NaN           NaN            NaN           0.0
# 1125       NaN       NaN           NaN            NaN           0.0
# 1147        Gd        TA            No            GLQ        1124.0
# 1157       NaN       NaN           NaN            NaN           0.0
# 1211       NaN       NaN           NaN            NaN           0.0
# 1222       NaN       NaN           NaN            NaN           0.0
# 1252       NaN       NaN           NaN            NaN           0.0
# 1256       NaN       NaN           NaN            NaN           0.0
# 1270       NaN       NaN           NaN            NaN           0.0
# 1327       NaN       NaN           NaN            NaN           NaN
# 1331       NaN       NaN           NaN            NaN           0.0
# 1377       NaN       NaN           NaN            NaN           0.0
# 1387       NaN       NaN           NaN            NaN           0.0
# 1428       NaN       NaN           NaN            NaN           0.0
# 1481       NaN       NaN           NaN            NaN           0.0
# 1594       NaN       NaN           NaN            NaN           0.0
# 1620       NaN       NaN           NaN            NaN           0.0
# 1681       NaN       NaN           NaN            NaN           0.0
# 1684       NaN       NaN           NaN            NaN           0.0
# 1686       NaN       NaN           NaN            NaN           0.0
# 1859       NaN       NaN           NaN            NaN           0.0
# 1875       NaN       NaN           NaN            NaN           0.0
# 1889       NaN       NaN           NaN            NaN           0.0
# 1933       NaN       NaN           NaN            NaN           0.0
# 2010       NaN       NaN           NaN            NaN           0.0
#
#      BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF
# 12              NaN           0.0          0.0            0.0
# 93              NaN           0.0          0.0            0.0
# 114             NaN           0.0          0.0            0.0
# 146             NaN           0.0          0.0            0.0
# 183             NaN           0.0          0.0            0.0
# 240             NaN           0.0          0.0            0.0
# 249             NaN           0.0          0.0            0.0
# 256             NaN           0.0          0.0            0.0
# 390             NaN           0.0          0.0            0.0
# 437             NaN           0.0          0.0            0.0
# 485             NaN           0.0          0.0            0.0
# 499             NaN           0.0          0.0            0.0
# 514             NaN           0.0          0.0            0.0
# 580             NaN           0.0          0.0            0.0
# 581             NaN           0.0          0.0            0.0
# 616             NaN           0.0          0.0            0.0
# 635             NaN           0.0          0.0            0.0
# 642             NaN           0.0          0.0            0.0
# 696             NaN           0.0          0.0            0.0
# 700             NaN           0.0          0.0            0.0
# 737             NaN           0.0          0.0            0.0
# 772             NaN           0.0          0.0            0.0
# 790             NaN           0.0          0.0            0.0
# 794             NaN           0.0          0.0            0.0
# 924             NaN           0.0          0.0            0.0
# 933             NaN           0.0          0.0            0.0
# 954             NaN           0.0          0.0            0.0
# 1007            NaN           0.0          0.0            0.0
# 1022            NaN           0.0          0.0            0.0
# 1049            NaN           0.0          0.0            0.0
# 1089            NaN           0.0          0.0            0.0
# 1098            NaN           0.0          0.0            0.0
# 1125            NaN           0.0          0.0            0.0
# 1147            NaN         479.0       1603.0         3206.0
# 1157            NaN           0.0          0.0            0.0
# 1211            NaN           0.0          0.0            0.0
# 1222            NaN           0.0          0.0            0.0
# 1252            NaN           0.0          0.0            0.0
# 1256            NaN           0.0          0.0            0.0
# 1270            NaN           0.0          0.0            0.0
# 1327            NaN           NaN          NaN            NaN
# 1331            NaN           0.0          0.0            0.0
# 1377            NaN           0.0          0.0            0.0
# 1387            NaN           0.0          0.0            0.0
# 1428            NaN           0.0          0.0            0.0
# 1481            NaN           0.0          0.0            0.0
# 1594            NaN           0.0          0.0            0.0
# 1620            NaN           0.0          0.0            0.0
# 1681            NaN           0.0          0.0            0.0
# 1684            NaN           0.0          0.0            0.0
# 1686            NaN           0.0          0.0            0.0
# 1859            NaN           0.0          0.0            0.0
# 1875            NaN           0.0          0.0            0.0
# 1889            NaN           0.0          0.0            0.0
# 1933            NaN           0.0          0.0            0.0
# 2010            NaN           0.0          0.0            0.0

# %% [markdown]
# It appears that BsmtFin Type 2 has an additional missing value compared to the baseline. As I would prefer to not impute values unless truly necessary, I decide to drop this one row of data due to its minute size.

# %%
train.drop(index=[1147],inplace=True)

# %%
train.shape
# Out:
# (2047, 81)

# %% [markdown]
# Next, I impute the missing values with 'NA' for all of the aforementioned basement related columns

# %%
basement = train.loc[:,['Bsmt Qual','Bsmt Cond','Bsmt Exposure','BsmtFin Type 1','BsmtFin Type 2']]

# %%
#Impute NaN values with the value 'NA':'No Basement'
#I apply imp2 (previously instantiated) to transform 
#'Bsmt Qual','Bsmt Cond','Bsmt Exposure','BsmtFin Type 1' and 'BsmtFin Type 2'
train.loc[:,['Bsmt Qual','Bsmt Cond','Bsmt Exposure','BsmtFin Type 1','BsmtFin Type 2']] = imp2.fit_transform(basement)

# %%
#Nan values successfully converted to NA values
train['Bsmt Qual'].value_counts()
# Out:
# TA      887
# Gd      860
# Ex      184
# Fa       60
# None     55
# Po        1
# Name: Bsmt Qual, dtype: int64

# %%
#I check to make sure that there are no more NaN values
train[train['BsmtFin Type 2'].isnull()].loc[:,'Bsmt Qual':'Total Bsmt SF']
# Out:
# Empty DataFrame
# Columns: [Bsmt Qual, Bsmt Cond, Bsmt Exposure, BsmtFin Type 1, BsmtFin SF 1, BsmtFin Type 2, BsmtFin SF 2, Bsmt Unf SF, Total Bsmt SF]
# Index: []

# %% [raw]
# Among the ordinal variables that contain null values, these remain:
#
#  58  Fireplace Qu     1051 non-null   object 	Ordinal
#  61  Garage Finish    1937 non-null   object 	Ordinal
#  64  Garage Qual      1937 non-null   object 	Ordinal
#  65  Garage Cond      1937 non-null   object 	Ordinal
#  73  Pool QC          9 non-null      object 	Ordinal
#  74  Fence            400 non-null    object 	Ordinal

# %% [markdown]
# # Fireplace imputation of missing data

# %%
#There are 999 properties with 0 fireplaces
train['Fireplaces'].value_counts(dropna=False)
# Out:
# 0    999
# 1    895
# 2    146
# 3      6
# 4      1
# Name: Fireplaces, dtype: int64

# %%
#There is a corresponding 999 missing values. As such, it is highly likely that the missing values are already 'NA'
#values: No Fireplace
train['Fireplace Qu'].value_counts(dropna=False)
# Out:
# NaN    999
# Gd     521
# TA     406
# Fa      59
# Ex      31
# Po      31
# Name: Fireplace Qu, dtype: int64

# %%
#Impute NaN values with the value 'NA':'No Fireplace'
#I apply imp2 (previously instantiated) to transform 'Garage Type'
train.loc[:,"Fireplace Qu"] = imp2.fit_transform(train['Fireplace Qu'].values.reshape(-1,1))

# %%
#I confirm that the NaN values are replaced with NA
train.loc[:,"Fireplace Qu"].value_counts(dropna=False)
# Out:
# None    999
# Gd      521
# TA      406
# Fa       59
# Ex       31
# Po       31
# Name: Fireplace Qu, dtype: int64

# %% [markdown]
# # Garage imputation of missing data

# %%
#I check and realise that all 3 variables hold the same number of missing values:
train[['Garage Finish','Garage Qual','Garage Cond']].isnull().sum()
# Out:
# Garage Finish    114
# Garage Qual      114
# Garage Cond      114
# dtype: int64

# %%
#I ascertain that there are 114 rows where all 3 variables have missing values
#Since the data description mentions that there are responses called NA which denote 'No Garage'
#I suspect that the missing values are NA responses
train[train['Garage Finish'].isnull() & train['Garage Qual'].isnull() & train['Garage Cond'].isnull()]
# Out:
#         Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 28    2243  911103060          190   C (all)          75.0      8250   Pave
# 53     330  923226250          160        RM          21.0      1476   Pave
# 65    2278  923202134           20        RL          70.0      8402   Pave
# 79    2235  910201050           50        RM          50.0      7288   Pave
# 101   2084  905476170           30        RL          58.0      9098   Pave
# ...    ...        ...          ...       ...           ...       ...    ...
# 1991   325  923204150           90        RL          94.0      9400   Pave
# 2010  2880  911175410           30   C (all)          69.0     12366   Pave
# 2027  2628  535456010           90        RL          75.0      8512   Pave
# 2039  2288  923228220          160        RM          21.0      1495   Pave
# 2042  2842  909101080           50        RL          45.0      8248   Pave
#
#      Alley Lot Shape Land Contour Utilities Lot Config Land Slope  \
# 28    None       Reg          Lvl    AllPub     Inside        Gtl
# 53    None       Reg          Lvl    AllPub     Inside        Gtl
# 65    None       Reg          Lvl    AllPub     Inside        Gtl
# 79    None       Reg          Lvl    AllPub     Inside        Gtl
# 101   None       IR1          Lvl    AllPub     Inside        Gtl
# ...    ...       ...          ...       ...        ...        ...
# 1991  None       Reg          Low    AllPub     Corner        Gtl
# 2010  None       Reg          Lvl    AllPub     Inside        Gtl
# 2027  None       Reg          Lvl    AllPub     Corner        Gtl
# 2039  None       Reg          Lvl    AllPub     Inside        Gtl
# 2042  Grvl       Reg          Lvl    AllPub     Inside        Gtl
#
#      Neighborhood Condition 1 Condition 2 Bldg Type House Style  Overall Qual  \
# 28         IDOTRR       Feedr        Norm    2fmCon      2Story             5
# 53        MeadowV        Norm        Norm     Twnhs      2Story             4
# 65        Mitchel       Feedr        Norm      1Fam      1Story             5
# 79         IDOTRR      Artery        Norm      1Fam      1.5Fin             5
# 101       Edwards        Norm        Norm      1Fam      1Story             4
# ...           ...         ...         ...       ...         ...           ...
# 1991      Mitchel        Norm        Norm    Duplex      2Story             6
# 2010       IDOTRR       Feedr        Norm      1Fam      1Story             3
# 2027        NAmes        Norm        Norm    Duplex      1Story             5
# 2039      MeadowV        Norm        Norm    TwnhsE      2Story             4
# 2042      Edwards        Norm        Norm      1Fam      1.5Fin             4
#
#       Overall Cond  Year Built  Year Remod/Add Roof Style Roof Matl  \
# 28               6        1895            2006      Gable   CompShg
# 53               7        1970            1970      Gable   CompShg
# 65               5        2007            2007      Gable   CompShg
# 79               7        1925            2003      Gable   CompShg
# 101              7        1920            2002      Gable   CompShg
# ...            ...         ...             ...        ...       ...
# 1991             5        1971            1971    Mansard   CompShg
# 2010             5        1945            1950      Gable   CompShg
# 2027             5        1960            1960        Hip   CompShg
# 2039             6        1970            1970      Gable   CompShg
# 2042             4        1922            1950      Gable   CompShg
#
#      Exterior 1st Exterior 2nd Mas Vnr Type  Mas Vnr Area Exter Qual  \
# 28        VinylSd      VinylSd         None           0.0         TA
# 53        CemntBd      CmentBd         None           0.0         TA
# 65        VinylSd      VinylSd         None           0.0         TA
# 79        VinylSd      VinylSd         None           0.0         Gd
# 101       Wd Sdng      Wd Sdng         None           0.0         TA
# ...           ...          ...          ...           ...        ...
# 1991      MetalSd      Wd Shng         None           0.0         TA
# 2010      Wd Sdng      Wd Sdng         None           0.0         TA
# 2027      BrkFace      BrkFace         None           0.0         TA
# 2039      CemntBd      CmentBd      BrkFace         189.0         TA
# 2042      Wd Sdng      Wd Sdng         None           0.0         TA
#
#      Exter Cond Foundation Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1  \
# 28           Gd     CBlock        TA        TA            No            Unf
# 53           TA     CBlock        TA        TA            No            GLQ
# 65           TA      PConc        Gd        TA            No            ALQ
# 79           Gd     BrkTil        TA        Po            No            Unf
# 101          TA     BrkTil        TA        TA            Mn            ALQ
# ...         ...        ...       ...       ...           ...            ...
# 1991         TA     CBlock        TA        TA            Av            Unf
# 2010         TA       Slab      None      None          None           None
# 2027         TA     CBlock        TA        Fa            No            Unf
# 2039         TA     CBlock        TA        TA            No            ALQ
# 2042         TA     BrkTil        TA        TA            No            Unf
#
#       BsmtFin SF 1 BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF  \
# 28             0.0            Unf           0.0        957.0          957.0
# 53           176.0            Unf           0.0        370.0          546.0
# 65           206.0            Unf           0.0        914.0         1120.0
# 79             0.0            Unf           0.0        936.0          936.0
# 101          348.0            Unf           0.0        180.0          528.0
# ...            ...            ...           ...          ...            ...
# 1991           0.0            Unf           0.0        912.0          912.0
# 2010           0.0           None           0.0          0.0            0.0
# 2027           0.0            Unf           0.0       1556.0         1556.0
# 2039         384.0            Unf           0.0        162.0          546.0
# 2042           0.0            Unf           0.0        864.0          864.0
#
#      Heating Heating QC Central Air Electrical  1st Flr SF  2nd Flr SF  \
# 28      GasA         Fa           N      SBrkr        1034         957
# 53      GasA         Ex           Y      SBrkr         546         546
# 65      GasA         Ex           Y      SBrkr        1120           0
# 79      GasA         Ex           Y      SBrkr         936         665
# 101     GasA         Ex           Y      SBrkr         605           0
# ...      ...        ...         ...        ...         ...         ...
# 1991    GasA         TA           Y      SBrkr         912         912
# 2010    GasA         TA           N      SBrkr         729           0
# 2027    GasA         TA           Y      SBrkr        1556           0
# 2039    GasA         Ex           Y      SBrkr         546         546
# 2042    GasA         TA           N      SBrkr         964           0
#
#       Low Qual Fin SF  Gr Liv Area  Bsmt Full Bath  Bsmt Half Bath  Full Bath  \
# 28                  0         1991             0.0             0.0          2
# 53                  0         1092             0.0             0.0          1
# 65                  0         1120             0.0             0.0          1
# 79                  0         1601             0.0             0.0          2
# 101                 0          605             1.0             0.0          1
# ...               ...          ...             ...             ...        ...
# 1991                0         1824             0.0             0.0          2
# 2010                0          729             0.0             0.0          1
# 2027                0         1556             0.0             0.0          2
# 2039                0         1092             0.0             0.0          1
# 2042              450         1414             0.0             0.0          1
#
#       Half Bath  Bedroom AbvGr  Kitchen AbvGr Kitchen Qual  TotRms AbvGrd  \
# 28            0              4              2           TA              9
# 53            1              3              1           TA              5
# 65            0              3              1           TA              6
# 79            0              3              1           TA              6
# 101           0              2              1           TA              5
# ...         ...            ...            ...          ...            ...
# 1991          2              4              2           TA              8
# 2010          0              2              1           TA              5
# 2027          0              4              2           TA              8
# 2039          1              3              1           TA              5
# 2042          0              3              1           TA              8
#
#      Functional  Fireplaces Fireplace Qu Garage Type  Garage Yr Blt  \
# 28          Typ           0         None        None            NaN
# 53          Typ           0         None        None            NaN
# 65          Typ           0         None        None            NaN
# 79          Typ           0         None        None            NaN
# 101         Typ           0         None        None            NaN
# ...         ...         ...          ...         ...            ...
# 1991        Typ           0         None        None            NaN
# 2010        Mod           0         None        None            NaN
# 2027        Typ           0         None        None            NaN
# 2039        Typ           0         None        None            NaN
# 2042        Typ           1           Gd        None            NaN
#
#      Garage Finish  Garage Cars  Garage Area Garage Qual Garage Cond  \
# 28             NaN          0.0          0.0         NaN         NaN
# 53             NaN          0.0          0.0         NaN         NaN
# 65             NaN          0.0          0.0         NaN         NaN
# 79             NaN          0.0          0.0         NaN         NaN
# 101            NaN          0.0          0.0         NaN         NaN
# ...            ...          ...          ...         ...         ...
# 1991           NaN          0.0          0.0         NaN         NaN
# 2010           NaN          0.0          0.0         NaN         NaN
# 2027           NaN          0.0          0.0         NaN         NaN
# 2039           NaN          0.0          0.0         NaN         NaN
# 2042           NaN          0.0          0.0         NaN         NaN
#
#      Paved Drive  Wood Deck SF  Open Porch SF  Enclosed Porch  3Ssn Porch  \
# 28             N             0              0             133           0
# 53             Y           200             26               0           0
# 65             Y             0             30               0           0
# 79             N             0              0               0         176
# 101            N             0              0             144           0
# ...          ...           ...            ...             ...         ...
# 1991           Y           128              0               0           0
# 2010           N             0              0              23           0
# 2027           Y             0              0               0           0
# 2039           Y             0             64               0           0
# 2042           N             0              0             112           0
#
#       Screen Porch  Pool Area Pool QC Fence Misc Feature  Misc Val  Mo Sold  \
# 28               0          0     NaN   NaN         None         0        6
# 53               0          0     NaN   NaN         None         0        3
# 65               0          0     NaN   NaN         None         0       12
# 79               0          0     NaN   NaN         None         0        9
# 101              0          0     NaN   NaN         None         0        7
# ...            ...        ...     ...   ...          ...       ...      ...
# 1991             0          0     NaN   NaN         None         0        4
# 2010             0          0     NaN   NaN         None         0       10
# 2027             0          0     NaN   NaN         None         0        9
# 2039             0          0     NaN   NaN         None         0        5
# 2042             0          0     NaN   NaN         None         0        9
#
#       Yr Sold Sale Type  SalePrice
# 28       2007       WD      119600
# 53       2010       WD       76000
# 65       2007       New     147000
# 79       2007       WD      129850
# 101      2007       WD       86000
# ...       ...       ...        ...
# 1991     2010       WD      139000
# 2010     2006       WD       51689
# 2027     2006       WD      119000
# 2039     2007       WD       93900
# 2042     2006       COD      83000
#
# [114 rows x 81 columns]

# %%
garage = train.loc[:,['Garage Finish','Garage Qual','Garage Cond']]

# %%
#Impute NaN values with the value 'NA':'No Garage'
#I apply imp2 (previously instantiated) to transform 
#'Garage Finish','Garage Qual','Garage Cond'
train.loc[:,['Garage Finish','Garage Qual','Garage Cond']] = imp2.fit_transform(garage)

# %%
#No Nan values remaining among garage ordinal variables
train[train['Garage Finish'].isnull() & train['Garage Qual'].isnull() & train['Garage Cond'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, PID, MS SubClass, MS Zoning, Lot Frontage, Lot Area, Street, Alley, Lot Shape, Land Contour, Utilities, Lot Config, Land Slope, Neighborhood, Condition 1, Condition 2, Bldg Type, House Style, Overall Qual, Overall Cond, Year Built, Year Remod/Add, Roof Style, Roof Matl, Exterior 1st, Exterior 2nd, Mas Vnr Type, Mas Vnr Area, Exter Qual, Exter Cond, Foundation, Bsmt Qual, Bsmt Cond, Bsmt Exposure, BsmtFin Type 1, BsmtFin SF 1, BsmtFin Type 2, BsmtFin SF 2, Bsmt Unf SF, Total Bsmt SF, Heating, Heating QC, Central Air, Electrical, 1st Flr SF, 2nd Flr SF, Low Qual Fin SF, Gr Liv Area, Bsmt Full Bath, Bsmt Half Bath, Full Bath, Half Bath, Bedroom AbvGr, Kitchen AbvGr, Kitchen Qual, TotRms AbvGrd, Functional, Fireplaces, Fireplace Qu, Garage Type, Garage Yr Blt, Garage Finish, Garage Cars, Garage Area, Garage Qual, Garage Cond, Paved Drive, Wood Deck SF, Open Porch SF, Enclosed Porch, 3Ssn Porch, Screen Porch, Pool Area, Pool QC, Fence, Misc Feature, Misc Val, Mo Sold, Yr Sold, Sale Type, SalePrice]
# Index: []

# %% [raw]
# Finally we are down to
#
#  73  Pool QC          9 non-null      object 	Ordinal
#  74  Fence            400 non-null    object 	Ordinal

# %% [markdown]
# # Pool imputation of missing data

# %%
#There 2038 missing values
train['Pool QC'].value_counts(dropna=False)
# Out:
# NaN    2038
# Gd        4
# Fa        2
# TA        2
# Ex        1
# Name: Pool QC, dtype: int64

# %%
#There are 2038 'pools' with 0 area, which means that the 2038 missing values are in fact nonexistent pools
train['Pool Area'].value_counts(dropna=False)
# Out:
# 0      2038
# 800       1
# 738       1
# 648       1
# 576       1
# 561       1
# 519       1
# 480       1
# 368       1
# 228       1
# Name: Pool Area, dtype: int64

# %%
#Impute NaN values with the value 'NA':'No pool' (in accordance to the data description)
#I apply imp2 (previously instantiated) to transform 'Garage Type'
train.loc[:,"Pool QC"] = imp2.fit_transform(train['Pool QC'].values.reshape(-1,1))

# %%
#I confirm that null values are imputed with 'NA'
train['Pool QC'].value_counts(dropna=False)
# Out:
# None    2038
# Gd         4
# Fa         2
# TA         2
# Ex         1
# Name: Pool QC, dtype: int64

# %% [markdown]
# # Fence imputation of missing data

# %%
#The data description mentioned a value NA: No fence, which is not shown here. As such, I suspect that the 
#Missing values could be the NA values.
train['Fence'].value_counts(dropna=False)
# Out:
# NaN      1647
# MnPrv     227
# GdPrv      83
# GdWo       80
# MnWw       10
# Name: Fence, dtype: int64

# %%
#Impute NaN values with the value 'NA':'No fence' (in accordance to the data description)
#I apply imp2 (previously instantiated) to transform 'Fence'
train.loc[:,"Fence"] = imp2.fit_transform(train['Fence'].values.reshape(-1,1))

# %%
#Check that null values are successfully imputed with NA values
train['Fence'].value_counts(dropna=False)
# Out:
# None     1647
# MnPrv     227
# GdPrv      83
# GdWo       80
# MnWw       10
# Name: Fence, dtype: int64

# %% [markdown]
# # Imputation of Ordinal variables into numbers

# %% [markdown]
# The following 21 ordinal variables are to be imputed with a numerical number. The numbers are linked to how positive/negative the response is. eg. 5 for excellent, 2 for good, -5 for poor.
#
# Some variables may not have negative values, as the responses are determined to be additional features on top of a baseline(good to have). eg. Pool Quality
#
# Some variables may not have positive values, as the responses are determined to be a sequential deterioration eg. Functional(the house possessing typical functionalities)

# %%
train['Lot Shape'] = train['Lot Shape'].map({'Reg':2,'IR1':1,'IR2':0,'IR3':-1})

# %%
train['Utilities'] = train['Utilities'].map({'AllPub':2,'NoSewr':1,'NoSeWa':0})

# %%
#Most properties are flat, so i penalize for slopes/severe slopes
train['Land Slope'] = train['Land Slope'].map({'Gtl':0,'Mod':-1,'Sev':-2})

# %%
#The next four variables follow the same rating system according to the data description
#I give higher weight to the extreme variables, as they will likely have bigger influence
train['Exter Qual'] = train['Exter Qual'].map({'Ex':5,'Gd':2,'TA':0,'Fa':-2,'Po':-5})
train['Exter Cond'] = train['Exter Cond'].map({'Ex':5,'Gd':2,'TA':0,'Fa':-2,'Po':-5})
train['Heating QC'] = train['Heating QC'].map({'Ex':5,'Gd':2,'TA':0,'Fa':-2,'Po':-5})
train['Kitchen Qual'] = train['Kitchen Qual'].map({'Ex':5,'Gd':2,'TA':0,'Fa':-2,'Po':-5})

# %%
train['Bsmt Qual'] = train['Bsmt Qual'].map({'Ex':5,'Gd':2,'TA':0,'Fa':-1,'Po':-2,'None':-5})
train['Bsmt Cond'] = train['Bsmt Cond'].map({'Ex':5,'Gd':2,'TA':0,'Fa':-1,'Po':-2,'None':-5})

# %%
train['Bsmt Exposure'] = train['Bsmt Exposure'].map({'Gd':5,'Av':2,'Mn':0,'No':-2,'None':-5})

# %%
#These two variables follow the same rating system according to the data description
train['BsmtFin Type 1'] = train['BsmtFin Type 1'].map({'GLQ':5,'ALQ':2,'BLQ':1,'Rec':0,'LwQ':-1,'Unf':-2,'None':-5})
train['BsmtFin Type 2'] = train['BsmtFin Type 2'].map({'GLQ':5,'ALQ':2,'BLQ':1,'Rec':0,'LwQ':-1,'Unf':-2,'None':-5})

# %%
train['Electrical'] = train['Electrical'].map({'SBrkr':5,'FuseA':2,'FuseF':0,'FuseP':-2,'Mix':-5})

# %%
train['Electrical'].isnull().sum()
# Out:
# 0

# %%
#I weigh negative factors more heavily as I believe home owners expect typical functionality to be present
train['Functional'] = train['Functional'].map({'Typ':3,'Min1':2,'Min2':1,'Mod':0,'Maj1':-1,'Maj2':-2,'Sev':-5,'Sal':-8})

# %%
#These two variables follow the same rating system according to the data description
train['Fireplace Qu'] = train['Fireplace Qu'].map({'Ex':5,'Gd':2,'TA':0,'Fa':-1,'Po':-2,'None':-5})
train['Garage Qual'] = train['Garage Qual'].map({'Ex':5,'Gd':2,'TA':0,'Fa':-1,'Po':-2,'None':-5})
train['Garage Cond'] = train['Garage Cond'].map({'Ex':5,'Gd':2,'TA':0,'Fa':-1,'Po':-2,'None':-5})

# %%
#I did not include 0 as I do not consider any of the response neutral
train['Garage Finish'] = train['Garage Finish'].map({'Fin':5,'RFn':2,'Unf':-2,'None':-5})

# %%
train['Paved Drive'] = train['Paved Drive'].map({'Y':3,'P':0,'N':3})

# %%
#I consider pools to be a luxury item, and hence the scales are 
#largely positive
train['Pool QC'] = train['Pool QC'].map({'Ex':6,'Gd':3,'TA':2,'Fa':1,'None':0})

# %%
train['Fence'] = train['Fence'].map({'GdPrv':5,'MnPrv':2,'GdWo':1,'MnWw':-1,'None':-3})

# %% [markdown]
# # Imputation of continuous variables
#
# The following is a list of the continuous variables(before processing), of which some are missing values. Mas Vnr Area has already been processed with Mas Vnr Type, and hence will be excluded at this step.

# %% [raw]
#  4   Lot Frontage     1721 non-null   float64	Continuous
#  5   Lot Area         2051 non-null   int64  	Continuous
#  27  Mas Vnr Area     2029 non-null   float64	Continuous
#  35  BsmtFin SF 1     2050 non-null   float64	Continuous
#  37  BsmtFin SF 2     2050 non-null   float64	Continuous
#  38  Bsmt Unf SF      2050 non-null   float64	Continuous
#  39  Total Bsmt SF    2050 non-null   float64	Continuous
#  44  1st Flr SF       2051 non-null   int64  	Continuous
#  45  2nd Flr SF       2051 non-null   int64  	Continuous
#  46  Low Qual Fin SF  2051 non-null   int64  	Continuous
#  47  Gr Liv Area      2051 non-null   int64  	Continuous
#  63  Garage Area      2050 non-null   float64	Continuous
#  67  Wood Deck SF     2051 non-null   int64  	Continuous
#  68  Open Porch SF    2051 non-null   int64  	Continuous
#  69  Enclosed Porch   2051 non-null   int64  	Continuous
#  70  3Ssn Porch       2051 non-null   int64  	Continuous
#  71  Screen Porch     2051 non-null   int64  	Continuous
#  72  Pool Area        2051 non-null   int64  	Continuous
#  76  Misc Val         2051 non-null   int64  	Continuous
#  80  SalePrice        2051 non-null   int64 	Continuous

# %% [markdown]
# As such, most of them can be used as is, and I will process only the variables that are missing values:

# %% [raw]
#  4   Lot Frontage     1721 non-null   float64	Continuous
#  35  BsmtFin SF 1     2050 non-null   float64	Continuous
#  37  BsmtFin SF 2     2050 non-null   float64	Continuous
#  38  Bsmt Unf SF      2050 non-null   float64	Continuous
#  39  Total Bsmt SF    2050 non-null   float64	Continuous
#  63  Garage Area      2050 non-null   float64	Continuous

# %% [markdown]
# # Lot Frontage Imputation

# %%
train["Lot Frontage"].value_counts(dropna=False)
# Out:
# NaN      330
# 60.0     179
# 70.0      96
# 80.0      94
# 50.0      90
#         ...
# 141.0      1
# 135.0      1
# 155.0      1
# 33.0       1
# 137.0      1
# Name: Lot Frontage, Length: 119, dtype: int64

# %%
train["Lot Frontage"].describe()
# Out:
# count    1717.000000
# mean       69.039022
# std        23.282375
# min        21.000000
# 25%        58.000000
# 50%        68.000000
# 75%        80.000000
# max       313.000000
# Name: Lot Frontage, dtype: float64

# %%
#As there are significant numbers of missing values, it would not make sense to impute 0 as a value, as
#It would skew the data. As such, I decide to Impute the missing values with the mean of the variable
#Impute NaN values with the value 69.0 (mean of the variable)
imp3 = SimpleImputer(missing_values=np.nan, fill_value=69.0, strategy='constant')
train.loc[:,"Lot Frontage"] = imp3.fit_transform(train['Lot Frontage'].values.reshape(-1,1))

# %%
#ascertain that mean value has been imputed
train["Lot Frontage"].value_counts(dropna=False)
# Out:
# 69.0     344
# 60.0     179
# 70.0      96
# 80.0      94
# 50.0      90
#         ...
# 195.0      1
# 141.0      1
# 135.0      1
# 33.0       1
# 137.0      1
# Name: Lot Frontage, Length: 118, dtype: int64

# %% [markdown]
# # Basement Imputation

# %% [raw]
#  35  BsmtFin SF 1     2050 non-null   float64	Continuous
#  37  BsmtFin SF 2     2050 non-null   float64	Continuous
#  38  Bsmt Unf SF      2050 non-null   float64	Continuous
#  39  Total Bsmt SF    2050 non-null   float64	Continuous

# %%
#It appears that the missing values among these 4 variables all come from the same property
train[train['BsmtFin SF 1'].isnull()]
# Out:
#         Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 1327  1342  903230120           20        RM          99.0      5940   Pave
#
#      Alley  Lot Shape Land Contour  Utilities Lot Config  Land Slope  \
# 1327  None          1          Lvl          2        FR3           0
#
#      Neighborhood Condition 1 Condition 2 Bldg Type House Style  Overall Qual  \
# 1327      BrkSide       Feedr        Norm      1Fam      1Story             4
#
#       Overall Cond  Year Built  Year Remod/Add Roof Style Roof Matl  \
# 1327             7        1946            1950      Gable   CompShg
#
#      Exterior 1st Exterior 2nd Mas Vnr Type  Mas Vnr Area  Exter Qual  \
# 1327      MetalSd       CBlock         None           0.0           0
#
#       Exter Cond Foundation  Bsmt Qual  Bsmt Cond  Bsmt Exposure  \
# 1327           0      PConc         -5         -5             -5
#
#       BsmtFin Type 1  BsmtFin SF 1  BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  \
# 1327              -5           NaN              -5           NaN          NaN
#
#       Total Bsmt SF Heating  Heating QC Central Air  Electrical  1st Flr SF  \
# 1327            NaN    GasA           0           Y           2         896
#
#       2nd Flr SF  Low Qual Fin SF  Gr Liv Area  Bsmt Full Bath  \
# 1327           0                0          896             NaN
#
#       Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  Kitchen AbvGr  \
# 1327             NaN          1          0              2              1
#
#       Kitchen Qual  TotRms AbvGrd  Functional  Fireplaces  Fireplace Qu  \
# 1327             0              4           3           0            -5
#
#      Garage Type  Garage Yr Blt  Garage Finish  Garage Cars  Garage Area  \
# 1327      Detchd         1946.0             -2          1.0        280.0
#
#       Garage Qual  Garage Cond  Paved Drive  Wood Deck SF  Open Porch SF  \
# 1327            0            0            3             0              0
#
#       Enclosed Porch  3Ssn Porch  Screen Porch  Pool Area  Pool QC  Fence  \
# 1327               0           0             0          0        0      2
#
#      Misc Feature  Misc Val  Mo Sold  Yr Sold Sale Type  SalePrice
# 1327         None         0        4     2008     ConLD      79000

# %%
#I decide to drop the row as it is only a single row, and I do not want to impute values where possible
train.drop(index=[1327],inplace=True)

# %%
#Row successfully dropped
train[train['BsmtFin SF 1'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, PID, MS SubClass, MS Zoning, Lot Frontage, Lot Area, Street, Alley, Lot Shape, Land Contour, Utilities, Lot Config, Land Slope, Neighborhood, Condition 1, Condition 2, Bldg Type, House Style, Overall Qual, Overall Cond, Year Built, Year Remod/Add, Roof Style, Roof Matl, Exterior 1st, Exterior 2nd, Mas Vnr Type, Mas Vnr Area, Exter Qual, Exter Cond, Foundation, Bsmt Qual, Bsmt Cond, Bsmt Exposure, BsmtFin Type 1, BsmtFin SF 1, BsmtFin Type 2, BsmtFin SF 2, Bsmt Unf SF, Total Bsmt SF, Heating, Heating QC, Central Air, Electrical, 1st Flr SF, 2nd Flr SF, Low Qual Fin SF, Gr Liv Area, Bsmt Full Bath, Bsmt Half Bath, Full Bath, Half Bath, Bedroom AbvGr, Kitchen AbvGr, Kitchen Qual, TotRms AbvGrd, Functional, Fireplaces, Fireplace Qu, Garage Type, Garage Yr Blt, Garage Finish, Garage Cars, Garage Area, Garage Qual, Garage Cond, Paved Drive, Wood Deck SF, Open Porch SF, Enclosed Porch, 3Ssn Porch, Screen Porch, Pool Area, Pool QC, Fence, Misc Feature, Misc Val, Mo Sold, Yr Sold, Sale Type, SalePrice]
# Index: []

# %% [markdown]
# # Garage Imputation

# %%
train['Garage Area'].isnull().sum()
# Out:
# 1

# %%
train[train['Garage Area'].isnull()]
# Out:
#         Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 1712  2237  910201180           70        RM          50.0      9060   Pave
#
#      Alley  Lot Shape Land Contour  Utilities Lot Config  Land Slope  \
# 1712  None          2          Lvl          2     Inside           0
#
#      Neighborhood Condition 1 Condition 2 Bldg Type House Style  Overall Qual  \
# 1712       IDOTRR        Norm        Norm      1Fam      2Story             5
#
#       Overall Cond  Year Built  Year Remod/Add Roof Style Roof Matl  \
# 1712             6        1923            1999      Gable   CompShg
#
#      Exterior 1st Exterior 2nd Mas Vnr Type  Mas Vnr Area  Exter Qual  \
# 1712      Wd Sdng      Plywood         None           0.0           0
#
#       Exter Cond Foundation  Bsmt Qual  Bsmt Cond  Bsmt Exposure  \
# 1712           0     BrkTil          2          0             -2
#
#       BsmtFin Type 1  BsmtFin SF 1  BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  \
# 1712               2         548.0              -2           0.0        311.0
#
#       Total Bsmt SF Heating  Heating QC Central Air  Electrical  1st Flr SF  \
# 1712          859.0    GasA           5           Y           5         942
#
#       2nd Flr SF  Low Qual Fin SF  Gr Liv Area  Bsmt Full Bath  \
# 1712         886                0         1828             0.0
#
#       Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  Kitchen AbvGr  \
# 1712             0.0          2          0              3              1
#
#       Kitchen Qual  TotRms AbvGrd  Functional  Fireplaces  Fireplace Qu  \
# 1712             2              6           3           0            -5
#
#      Garage Type  Garage Yr Blt  Garage Finish  Garage Cars  Garage Area  \
# 1712      Detchd            NaN             -5          NaN          NaN
#
#       Garage Qual  Garage Cond  Paved Drive  Wood Deck SF  Open Porch SF  \
# 1712           -5           -5            3           174              0
#
#       Enclosed Porch  3Ssn Porch  Screen Porch  Pool Area  Pool QC  Fence  \
# 1712             212           0             0          0        0      2
#
#      Misc Feature  Misc Val  Mo Sold  Yr Sold Sale Type  SalePrice
# 1712         None         0        3     2007       WD      150909

# %%
#I decide to drop the row as it is only a single row, and I do not want to impute values where possible
train.drop(index=1712,inplace=True)

# %%
#Ascertain that the row is dropped
train[train['Garage Area'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, PID, MS SubClass, MS Zoning, Lot Frontage, Lot Area, Street, Alley, Lot Shape, Land Contour, Utilities, Lot Config, Land Slope, Neighborhood, Condition 1, Condition 2, Bldg Type, House Style, Overall Qual, Overall Cond, Year Built, Year Remod/Add, Roof Style, Roof Matl, Exterior 1st, Exterior 2nd, Mas Vnr Type, Mas Vnr Area, Exter Qual, Exter Cond, Foundation, Bsmt Qual, Bsmt Cond, Bsmt Exposure, BsmtFin Type 1, BsmtFin SF 1, BsmtFin Type 2, BsmtFin SF 2, Bsmt Unf SF, Total Bsmt SF, Heating, Heating QC, Central Air, Electrical, 1st Flr SF, 2nd Flr SF, Low Qual Fin SF, Gr Liv Area, Bsmt Full Bath, Bsmt Half Bath, Full Bath, Half Bath, Bedroom AbvGr, Kitchen AbvGr, Kitchen Qual, TotRms AbvGrd, Functional, Fireplaces, Fireplace Qu, Garage Type, Garage Yr Blt, Garage Finish, Garage Cars, Garage Area, Garage Qual, Garage Cond, Paved Drive, Wood Deck SF, Open Porch SF, Enclosed Porch, 3Ssn Porch, Screen Porch, Pool Area, Pool QC, Fence, Misc Feature, Misc Val, Mo Sold, Yr Sold, Sale Type, SalePrice]
# Index: []

# %% [markdown]
# # Imputation of discrete variables

# %% [markdown]
# The discrete variables can be split into two categories:
# - Those without null values:

# %% [raw]
#  20  Year Built       2051 non-null   int64  	Discrete
#  21  Year Remod/Add   2051 non-null   int64  	Discrete
#  50  Full Bath        2051 non-null   int64  	Discrete
#  51  Half Bath        2051 non-null   int64  	Discrete
#  52  Bedroom AbvGr    2051 non-null   int64  	Discrete
#  53  Kitchen AbvGr    2051 non-null   int64  	Discrete
#  55  TotRms AbvGrd    2051 non-null   int64  	Discrete
#  57  Fireplaces       2051 non-null   int64  	Discrete
#  77  Mo Sold          2051 non-null   int64  	Discrete
#  78  Yr Sold          2051 non-null   int64  	Discrete

# %% [markdown]
# - And those with null values:

# %% [raw]
#  48  Bsmt Full Bath   2049 non-null   float64	Discrete
#  49  Bsmt Half Bath   2049 non-null   float64	Discrete
#  60  Garage Yr Blt    1937 non-null   float64	Discrete
#  62  Garage Cars      2050 non-null   float64	Discrete

# %% [markdown]
# First, I will work on imputing the missing values that are found in the above 4 variables

# %% [markdown]
# # Basement-related imputation

# %%
train['Bsmt Full Bath'].value_counts(dropna=False)
# Out:
# 0.0    1196
# 1.0     823
# 2.0      23
# 3.0       2
# NaN       1
# Name: Bsmt Full Bath, dtype: int64

# %%
#As it appeears that for both these variables there are no basements in the house, I will impute the number of baths
#As 0.0 instead.
train[train['Bsmt Full Bath'].isnull()]
# Out:
#        Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 616  1498  908154080           20        RL         123.0     47007   Pave
#
#     Alley  Lot Shape Land Contour  Utilities Lot Config  Land Slope  \
# 616  None          1          Lvl          2     Inside           0
#
#     Neighborhood Condition 1 Condition 2 Bldg Type House Style  Overall Qual  \
# 616      Edwards        Norm        Norm      1Fam      1Story             5
#
#      Overall Cond  Year Built  Year Remod/Add Roof Style Roof Matl  \
# 616             7        1959            1996      Gable   CompShg
#
#     Exterior 1st Exterior 2nd Mas Vnr Type  Mas Vnr Area  Exter Qual  \
# 616      Plywood      Plywood         None           0.0           0
#
#      Exter Cond Foundation  Bsmt Qual  Bsmt Cond  Bsmt Exposure  \
# 616           0       Slab         -5         -5             -5
#
#      BsmtFin Type 1  BsmtFin SF 1  BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  \
# 616              -5           0.0              -5           0.0          0.0
#
#      Total Bsmt SF Heating  Heating QC Central Air  Electrical  1st Flr SF  \
# 616            0.0    GasA           0           Y           5        3820
#
#      2nd Flr SF  Low Qual Fin SF  Gr Liv Area  Bsmt Full Bath  Bsmt Half Bath  \
# 616           0                0         3820             NaN             NaN
#
#      Full Bath  Half Bath  Bedroom AbvGr  Kitchen AbvGr  Kitchen Qual  \
# 616          3          1              5              1             5
#
#      TotRms AbvGrd  Functional  Fireplaces  Fireplace Qu Garage Type  \
# 616             11           3           2             2      Attchd
#
#      Garage Yr Blt  Garage Finish  Garage Cars  Garage Area  Garage Qual  \
# 616         1959.0             -2          2.0        624.0            0
#
#      Garage Cond  Paved Drive  Wood Deck SF  Open Porch SF  Enclosed Porch  \
# 616            0            3             0            372               0
#
#      3Ssn Porch  Screen Porch  Pool Area  Pool QC  Fence Misc Feature  \
# 616           0             0          0        0     -3         None
#
#      Misc Val  Mo Sold  Yr Sold Sale Type  SalePrice
# 616         0        7     2008       WD      284700

# %%
#I impute the NaN value with 0.0
#I apply imp(previously instantiated) to replace 
imp4 = SimpleImputer(missing_values=np.nan, fill_value=0.0, strategy='constant')
train.loc[:,"Bsmt Full Bath":"Bsmt Half Bath"] = imp4.fit_transform(train.loc[:,"Bsmt Full Bath":"Bsmt Half Bath"])

# %%
#I ascertain that the NaN values are replaced
train[train['Bsmt Full Bath'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, PID, MS SubClass, MS Zoning, Lot Frontage, Lot Area, Street, Alley, Lot Shape, Land Contour, Utilities, Lot Config, Land Slope, Neighborhood, Condition 1, Condition 2, Bldg Type, House Style, Overall Qual, Overall Cond, Year Built, Year Remod/Add, Roof Style, Roof Matl, Exterior 1st, Exterior 2nd, Mas Vnr Type, Mas Vnr Area, Exter Qual, Exter Cond, Foundation, Bsmt Qual, Bsmt Cond, Bsmt Exposure, BsmtFin Type 1, BsmtFin SF 1, BsmtFin Type 2, BsmtFin SF 2, Bsmt Unf SF, Total Bsmt SF, Heating, Heating QC, Central Air, Electrical, 1st Flr SF, 2nd Flr SF, Low Qual Fin SF, Gr Liv Area, Bsmt Full Bath, Bsmt Half Bath, Full Bath, Half Bath, Bedroom AbvGr, Kitchen AbvGr, Kitchen Qual, TotRms AbvGrd, Functional, Fireplaces, Fireplace Qu, Garage Type, Garage Yr Blt, Garage Finish, Garage Cars, Garage Area, Garage Qual, Garage Cond, Paved Drive, Wood Deck SF, Open Porch SF, Enclosed Porch, 3Ssn Porch, Screen Porch, Pool Area, Pool QC, Fence, Misc Feature, Misc Val, Mo Sold, Yr Sold, Sale Type, SalePrice]
# Index: []

# %% [markdown]
# # Garage-related imputation

# %% [raw]
#  60  Garage Yr Blt    1937 non-null   float64	Discrete
#  62  Garage Cars      2050 non-null   float64	Discrete

# %%
train['Garage Yr Blt'].value_counts(dropna=False)
# Out:
# NaN       113
# 2005.0    104
# 2007.0     83
# 2006.0     80
# 2004.0     72
#          ...
# 1917.0      1
# 1919.0      1
# 1895.0      1
# 1896.0      1
# 2207.0      1
# Name: Garage Yr Blt, Length: 101, dtype: int64

# %%
train['Garage Yr Blt'].sort_values(ascending=False)
# Out:
# 1699    2207.0
# 144     2010.0
# 1241    2010.0
# 1732    2009.0
# 1796    2009.0
#          ...
# 1991       NaN
# 2010       NaN
# 2027       NaN
# 2039       NaN
# 2042       NaN
# Name: Garage Yr Blt, Length: 2045, dtype: float64

# %%
#I suspect that the garage year built of 2207 is in fact a typo, and should instead be 2007
#As such, I will replace it with 2007
train[train['Garage Yr Blt'] > 2010]
# Out:
#         Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 1699  2261  916384070           20        RL          68.0      8298   Pave
#
#      Alley  Lot Shape Land Contour  Utilities Lot Config  Land Slope  \
# 1699  None          1          HLS          2     Inside           0
#
#      Neighborhood Condition 1 Condition 2 Bldg Type House Style  Overall Qual  \
# 1699       Timber        Norm        Norm      1Fam      1Story             8
#
#       Overall Cond  Year Built  Year Remod/Add Roof Style Roof Matl  \
# 1699             5        2006            2007        Hip   CompShg
#
#      Exterior 1st Exterior 2nd Mas Vnr Type  Mas Vnr Area  Exter Qual  \
# 1699      VinylSd      VinylSd         None           0.0           2
#
#       Exter Cond Foundation  Bsmt Qual  Bsmt Cond  Bsmt Exposure  \
# 1699           0      PConc          2          0              2
#
#       BsmtFin Type 1  BsmtFin SF 1  BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  \
# 1699               5         583.0              -2           0.0        963.0
#
#       Total Bsmt SF Heating  Heating QC Central Air  Electrical  1st Flr SF  \
# 1699         1546.0    GasA           5           Y           5        1564
#
#       2nd Flr SF  Low Qual Fin SF  Gr Liv Area  Bsmt Full Bath  \
# 1699           0                0         1564             0.0
#
#       Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  Kitchen AbvGr  \
# 1699             0.0          2          0              2              1
#
#       Kitchen Qual  TotRms AbvGrd  Functional  Fireplaces  Fireplace Qu  \
# 1699             5              6           3           1             2
#
#      Garage Type  Garage Yr Blt  Garage Finish  Garage Cars  Garage Area  \
# 1699      Attchd         2207.0              2          2.0        502.0
#
#       Garage Qual  Garage Cond  Paved Drive  Wood Deck SF  Open Porch SF  \
# 1699            0            0            3           132              0
#
#       Enclosed Porch  3Ssn Porch  Screen Porch  Pool Area  Pool QC  Fence  \
# 1699               0           0             0          0        0     -3
#
#      Misc Feature  Misc Val  Mo Sold  Yr Sold Sale Type  SalePrice
# 1699         None         0        9     2007       New     267300

# %%
train['Garage Yr Blt'].replace(2207, 2007,inplace=True)

# %%
#Check to ascertain that the replacement is done
train[train['Garage Yr Blt'] > 2010]
# Out:
# Empty DataFrame
# Columns: [Id, PID, MS SubClass, MS Zoning, Lot Frontage, Lot Area, Street, Alley, Lot Shape, Land Contour, Utilities, Lot Config, Land Slope, Neighborhood, Condition 1, Condition 2, Bldg Type, House Style, Overall Qual, Overall Cond, Year Built, Year Remod/Add, Roof Style, Roof Matl, Exterior 1st, Exterior 2nd, Mas Vnr Type, Mas Vnr Area, Exter Qual, Exter Cond, Foundation, Bsmt Qual, Bsmt Cond, Bsmt Exposure, BsmtFin Type 1, BsmtFin SF 1, BsmtFin Type 2, BsmtFin SF 2, Bsmt Unf SF, Total Bsmt SF, Heating, Heating QC, Central Air, Electrical, 1st Flr SF, 2nd Flr SF, Low Qual Fin SF, Gr Liv Area, Bsmt Full Bath, Bsmt Half Bath, Full Bath, Half Bath, Bedroom AbvGr, Kitchen AbvGr, Kitchen Qual, TotRms AbvGrd, Functional, Fireplaces, Fireplace Qu, Garage Type, Garage Yr Blt, Garage Finish, Garage Cars, Garage Area, Garage Qual, Garage Cond, Paved Drive, Wood Deck SF, Open Porch SF, Enclosed Porch, 3Ssn Porch, Screen Porch, Pool Area, Pool QC, Fence, Misc Feature, Misc Val, Mo Sold, Yr Sold, Sale Type, SalePrice]
# Index: []

# %%
train['Garage Yr Blt'].mean()
# Out:
# 1978.5683229813665

# %%
train['Garage Yr Blt'].isnull().sum()
# Out:
# 113

# %%
#As done previously for the variables 'Garage Cond' and 'Garage Qual', it appears that the missing values signify
#That there is actually no garage. As such, for representation sake, I will impute the 'Garage Yr Blt' null values with
#The average of the year that was built - 1978

train['Garage Yr Blt'].fillna(1978,inplace=True)

# %% [markdown]
# # One-hot encoding the nominal variables

# %% [markdown]
# The following are the nominal variables to be one-hot encoded:

# %% [raw]
#  7   Alley            140 non-null    object 	Nominal
#  26  Mas Vnr Type     2029 non-null   object 	Nominal
#  59  Garage Type      1938 non-null   object 	Nominal
#  75  Misc Feature     65 non-null     object 	Nominal

# %%
#Prepare pandas to be able to view all the columns after one-hot encoding
pd.set_option('max_columns',250)

#One-hot encode the non-null nominal variables
train = pd.get_dummies(train, columns=["MS SubClass",
                                         "MS Zoning",
                                         "Street",
                                         "Land Contour",
                                         "Lot Config",
                                         "Neighborhood",
                                         "Condition 1",
                                         "Condition 2",
                                         "Bldg Type",
                                         "House Style",
                                         "Roof Style",
                                         "Roof Matl",
                                         "Exterior 1st",
                                         "Exterior 2nd",
                                         "Foundation",
                                         "Heating",
                                         "Central Air",
                                         "Sale Type",
                                         "Alley",
                                         "Mas Vnr Type",
                                         "Garage Type",
                                         "Misc Feature"],
                       )

# %%
#After cleaning and one-hot encoding, I have 213 variables(including target variable)
train.shape
# Out:
# (2045, 235)

# %%
#All the dataset for the training data has been cleaned
train.isnull().sum().sum()
# Out:
# 0

# %%
train['Lot Shape']
# Out:
# 0       1
# 1       1
# 2       2
# 3       2
# 4       1
#        ..
# 2046    1
# 2047    1
# 2048    2
# 2049    2
# 2050    2
# Name: Lot Shape, Length: 2045, dtype: int64

# %%
#A heat map showing the correlation between my X variables and target variable
figure = plt.figure(figsize=(14,50))
sns.heatmap(train.corr()[['SalePrice']].sort_values('SalePrice',ascending=False),annot=True, cmap='coolwarm', center=0);

# %% [markdown]
# # Test set data cleaning and imputation

# %%
test = pd.read_csv("../datasets/test.csv")

# %%
#Test has one less variable compared to the training set(minus target variable)
test.shape
# Out:
# (879, 80)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 879 entries, 0 to 878
# Data columns (total 80 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Id               879 non-null    int64
#  1   PID              879 non-null    int64
#  2   MS SubClass      879 non-null    int64
#  3   MS Zoning        879 non-null    object
#  4   Lot Frontage     719 non-null    float64
#  5   Lot Area         879 non-null    int64
#  6   Street           879 non-null    object
#  7   Alley            58 non-null     object
#  8   Lot Shape        879 non-null    object
#  9   Land Contour     879 non-null    object
#  10  Utilities        879 non-null    object
#  11  Lot Config       879 non-null    object
#  12  Land Slope       879 non-null    object
#  13  Neighborhood     879 non-null    object
#  14  Condition 1      879 non-null    object
#  15  Condition 2      879 non-null    object
#  16  Bldg Type        879 non-null    object
#  17  House Style      879 non-null    object
#  18  Overall Qual     879 non-null    int64
#  19  Overall Cond     879 non-null    int64
#  20  Year Built       879 non-null    int64
#  21  Year Remod/Add   879 non-null    int64
#  22  Roof Style       879 non-null    object
#  23  Roof Matl        879 non-null    object
#  24  Exterior 1st     879 non-null    object
#  25  Exterior 2nd     879 non-null    object
#  26  Mas Vnr Type     878 non-null    object
#  27  Mas Vnr Area     878 non-null    float64
#  28  Exter Qual       879 non-null    object
#  29  Exter Cond       879 non-null    object
#  30  Foundation       879 non-null    object
#  31  Bsmt Qual        854 non-null    object
#  32  Bsmt Cond        854 non-null    object
#  33  Bsmt Exposure    854 non-null    object
#  34  BsmtFin Type 1   854 non-null    object
#  35  BsmtFin SF 1     879 non-null    int64
#  36  BsmtFin Type 2   854 non-null    object
#  37  BsmtFin SF 2     879 non-null    int64
#  38  Bsmt Unf SF      879 non-null    int64
#  39  Total Bsmt SF    879 non-null    int64
#  40  Heating          879 non-null    object
#  41  Heating QC       879 non-null    object
#  42  Central Air      879 non-null    object
#  43  Electrical       878 non-null    object
#  44  1st Flr SF       879 non-null    int64
#  45  2nd Flr SF       879 non-null    int64
#  46  Low Qual Fin SF  879 non-null    int64
#  47  Gr Liv Area      879 non-null    int64
#  48  Bsmt Full Bath   879 non-null    int64
#  49  Bsmt Half Bath   879 non-null    int64
#  50  Full Bath        879 non-null    int64
#  51  Half Bath        879 non-null    int64
#  52  Bedroom AbvGr    879 non-null    int64
#  53  Kitchen AbvGr    879 non-null    int64
#  54  Kitchen Qual     879 non-null    object
#  55  TotRms AbvGrd    879 non-null    int64
#  56  Functional       879 non-null    object
#  57  Fireplaces       879 non-null    int64
#  58  Fireplace Qu     457 non-null    object
#  59  Garage Type      835 non-null    object
#  60  Garage Yr Blt    834 non-null    float64
#  61  Garage Finish    834 non-null    object
#  62  Garage Cars      879 non-null    int64
#  63  Garage Area      879 non-null    int64
#  64  Garage Qual      834 non-null    object
#  65  Garage Cond      834 non-null    object
#  66  Paved Drive      879 non-null    object
#  67  Wood Deck SF     879 non-null    int64
#  68  Open Porch SF    879 non-null    int64
#  69  Enclosed Porch   879 non-null    int64
#  70  3Ssn Porch       879 non-null    int64
#  71  Screen Porch     879 non-null    int64
#  72  Pool Area        879 non-null    int64
#  73  Pool QC          4 non-null      object
#  74  Fence            172 non-null    object
#  75  Misc Feature     41 non-null     object
#  76  Misc Val         879 non-null    int64
#  77  Mo Sold          879 non-null    int64
#  78  Yr Sold          879 non-null    int64
#  79  Sale Type        879 non-null    object
# dtypes: float64(3), int64(35), object(42)
# memory usage: 549.5+ KB

# %%
test.shape
# Out:
# (879, 80)

# %% [raw]
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#
#  -4   Lot Frontage     719 non-null    float64    Continuous
#  -7   Alley            58 non-null     object     Nominal
#  -26  Mas Vnr Type     878 non-null    object     Nominal
#  -27  Mas Vnr Area     878 non-null    float64    Continuous
#  -31  Bsmt Qual        854 non-null    object     Ordinal
#  -32  Bsmt Cond        854 non-null    object     Ordinal
#  -33  Bsmt Exposure    854 non-null    object     Ordinal
#  -34  BsmtFin Type 1   854 non-null    object     Ordinal
#  -36  BsmtFin Type 2   854 non-null    object     Ordinal
#  43  Electrical       878 non-null    object     Ordinal
#  -58  Fireplace Qu     457 non-null    object     Ordinal
#  -59  Garage Type      835 non-null    object     Nominal
#  60  Garage Yr Blt    834 non-null    float64    Discrete
#  -61  Garage Finish    834 non-null    object     Ordinal
#  -64  Garage Qual      834 non-null    object     Ordinal
#  -65  Garage Cond      834 non-null    object     Ordinal
#  -73  Pool QC          4 non-null      object     Ordinal
#  -74  Fence            172 non-null    object     Ordinal
#  -75  Misc Feature     41 non-null     object     Nominal

# %%
#Code to clean test set 
#Values that underwent imp3
imp3 = SimpleImputer(missing_values=np.nan, fill_value=69.0, strategy='constant')
test.loc[:,"Lot Frontage"] = imp3.fit_transform(test['Lot Frontage'].values.reshape(-1,1))

#Values that underwent imp2
imp2 = SimpleImputer(missing_values=np.nan, fill_value='None', strategy='constant')
test.loc[:,"Alley"] = imp2.fit_transform(test['Alley'].values.reshape(-1,1))
test.loc[:,"Garage Type"] = imp2.fit_transform(test['Garage Type'].values.reshape(-1,1))
test.loc[:,"Misc Feature"] = imp2.fit_transform(test['Misc Feature'].values.reshape(-1,1))
basement_test = test.loc[:,['Bsmt Qual','Bsmt Cond','Bsmt Exposure','BsmtFin Type 1','BsmtFin Type 2']]
test.loc[:,['Bsmt Qual','Bsmt Cond','Bsmt Exposure','BsmtFin Type 1','BsmtFin Type 2']] = imp2.fit_transform(basement_test)
test.loc[:,"Fireplace Qu"] = imp2.fit_transform(test['Fireplace Qu'].values.reshape(-1,1))
garage_test = test.loc[:,['Garage Finish','Garage Qual','Garage Cond']]
test.loc[:,['Garage Finish','Garage Qual','Garage Cond']] = imp2.fit_transform(garage_test)
test.loc[:,"Pool QC"] = imp2.fit_transform(test['Pool QC'].values.reshape(-1,1))
test.loc[:,"Fence"] = imp2.fit_transform(test['Fence'].values.reshape(-1,1))

#Values that underwent imp1
imp1 = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
test.loc[:,"Mas Vnr Type":"Mas Vnr Area"] = imp1.fit_transform(test.loc[:,"Mas Vnr Type":"Mas Vnr Area"])

#Values that underwent fillna:
test['Garage Yr Blt'].fillna(1978,inplace=True)
test['Electrical'].fillna('None',inplace=True)

# %%
#Prepare pandas to be able to view all the columns after one-hot encoding
pd.set_option('max_columns',250)

#One-hot encode the non-null nominal variables
test = pd.get_dummies(test, columns=["MS SubClass",
                                         "MS Zoning",
                                         "Street",
                                         "Land Contour",
                                         "Lot Config",
                                         "Neighborhood",
                                         "Condition 1",
                                         "Condition 2",
                                         "Bldg Type",
                                         "House Style",
                                         "Roof Style",
                                         "Roof Matl",
                                         "Exterior 1st",
                                         "Exterior 2nd",
                                         "Foundation",
                                         "Heating",
                                         "Central Air",
                                         "Sale Type",
                                         "Alley",
                                         "Mas Vnr Type",
                                         "Garage Type",
                                         "Misc Feature"],
                          
                      )

# %%
test['Lot Shape'] = test['Lot Shape'].map({'Reg':2,'IR1':1,'IR2':0,'IR3':-1})

test['Utilities'] = test['Utilities'].map({'AllPub':2,'NoSewr':1,'NoSeWa':0})

#Most properties are flat, so i penalize for slopes/severe slopes
test['Land Slope'] = test['Land Slope'].map({'Gtl':0,'Mod':-1,'Sev':-2})

#The next four variables follow the same rating system according to the data description
#I give higher weight to the extreme variables, as they will likely have bigger influence
test['Exter Qual'] = test['Exter Qual'].map({'Ex':5,'Gd':2,'TA':0,'Fa':-2,'Po':-5})
test['Exter Cond'] = test['Exter Cond'].map({'Ex':5,'Gd':2,'TA':0,'Fa':-2,'Po':-5})
test['Heating QC'] = test['Heating QC'].map({'Ex':5,'Gd':2,'TA':0,'Fa':-2,'Po':-5})
test['Kitchen Qual'] = test['Kitchen Qual'].map({'Ex':5,'Gd':2,'TA':0,'Fa':-2,'Po':-5})

test['Bsmt Qual'] = test['Bsmt Qual'].map({'Ex':5,'Gd':2,'TA':0,'Fa':-1,'Po':-2,'None':-5})
test['Bsmt Cond'] = test['Bsmt Cond'].map({'Ex':5,'Gd':2,'TA':0,'Fa':-1,'Po':-2,'None':-5})

test['Bsmt Exposure'] = test['Bsmt Exposure'].map({'Gd':5,'Av':2,'Mn':0,'No':-2,'None':-5})

#These two variables follow the same rating system according to the data description
test['BsmtFin Type 1'] = test['BsmtFin Type 1'].map({'GLQ':5,'ALQ':2,'BLQ':1,'Rec':0,'LwQ':-1,'Unf':-2,'None':-5})
test['BsmtFin Type 2'] = test['BsmtFin Type 2'].map({'GLQ':5,'ALQ':2,'BLQ':1,'Rec':0,'LwQ':-1,'Unf':-2,'None':-5})

test['Electrical'] = test['Electrical'].map({'SBrkr':5,'FuseA':2,'FuseF':0,'FuseP':-2,'Mix':-5,'None':0})

#I weigh negative factors more heavily as I believe home owners expect typical functionality to be present
test['Functional'] = test['Functional'].map({'Typ':3,'Min1':2,'Min2':1,'Mod':0,'Maj1':-1,'Maj2':-2,'Sev':-5,'Sal':-8})


#These two variables follow the same rating system according to the data description
test['Fireplace Qu'] = test['Fireplace Qu'].map({'Ex':5,'Gd':2,'TA':0,'Fa':-1,'Po':-2,'None':-5})
test['Garage Qual'] = test['Garage Qual'].map({'Ex':5,'Gd':2,'TA':0,'Fa':-1,'Po':-2,'None':-5})
test['Garage Cond'] = test['Garage Cond'].map({'Ex':5,'Gd':2,'TA':0,'Fa':-1,'Po':-2,'None':-5})

#I did not include 0 as I do not consider any of the response neutral
test['Garage Finish'] = test['Garage Finish'].map({'Fin':5,'RFn':2,'Unf':-2,'None':-5})

test['Paved Drive'] = test['Paved Drive'].map({'Y':3,'P':0,'N':3})

#I consider pools to be a luxury item, and hence the scales are 
#largely positive
test['Pool QC'] = test['Pool QC'].map({'Ex':6,'Gd':3,'TA':2,'Fa':1,'None':0})

test['Fence'] = test['Fence'].map({'GdPrv':5,'MnPrv':2,'GdWo':1,'MnWw':-1,'None':-3})

# %%
test.isnull().sum().sum()
# Out:
# 0

# %%
train.shape
# Out:
# (2045, 235)

# %%
for i in train.columns:
    print(i)
# Out:
# Id
# PID
# Lot Frontage
# Lot Area
# Lot Shape
# Utilities
# Land Slope
# Overall Qual
# Overall Cond
# Year Built
# Year Remod/Add
# Mas Vnr Area
# Exter Qual
# Exter Cond
# Bsmt Qual
# Bsmt Cond
# Bsmt Exposure
# BsmtFin Type 1
# BsmtFin SF 1
# BsmtFin Type 2
# BsmtFin SF 2
# Bsmt Unf SF
# Total Bsmt SF
# Heating QC
# Electrical
# 1st Flr SF
# 2nd Flr SF
# Low Qual Fin SF
# Gr Liv Area
# Bsmt Full Bath
# Bsmt Half Bath
# Full Bath
# Half Bath
# Bedroom AbvGr
# Kitchen AbvGr
# Kitchen Qual
# TotRms AbvGrd
# Functional
# Fireplaces
# Fireplace Qu
# Garage Yr Blt
# Garage Finish
# Garage Cars
# Garage Area
# Garage Qual
# Garage Cond
# Paved Drive
# Wood Deck SF
# Open Porch SF
# Enclosed Porch
# 3Ssn Porch
# Screen Porch
# Pool Area
# Pool QC
# Fence
# Misc Val
# Mo Sold
# Yr Sold
# SalePrice
# MS SubClass_20
# MS SubClass_30
# MS SubClass_40
# MS SubClass_45
# MS SubClass_50
# MS SubClass_60
# MS SubClass_70
# MS SubClass_75
# MS SubClass_80
# MS SubClass_85
# MS SubClass_90
# MS SubClass_120
# MS SubClass_150
# MS SubClass_160
# MS SubClass_180
# MS SubClass_190
# MS Zoning_A (agr)
# MS Zoning_C (all)
# MS Zoning_FV
# MS Zoning_I (all)
# MS Zoning_RH
# MS Zoning_RL
# MS Zoning_RM
# Street_Grvl
# Street_Pave
# Land Contour_Bnk
# Land Contour_HLS
# Land Contour_Low
# Land Contour_Lvl
# Lot Config_Corner
# Lot Config_CulDSac
# Lot Config_FR2
# Lot Config_FR3
# Lot Config_Inside
# Neighborhood_Blmngtn
# Neighborhood_Blueste
# Neighborhood_BrDale
# Neighborhood_BrkSide
# Neighborhood_ClearCr
# Neighborhood_CollgCr
# Neighborhood_Crawfor
# Neighborhood_Edwards
# Neighborhood_Gilbert
# Neighborhood_Greens
# Neighborhood_GrnHill
# Neighborhood_IDOTRR
# Neighborhood_Landmrk
# Neighborhood_MeadowV
# Neighborhood_Mitchel
# Neighborhood_NAmes
# Neighborhood_NPkVill
# Neighborhood_NWAmes
# Neighborhood_NoRidge
# Neighborhood_NridgHt
# Neighborhood_OldTown
# Neighborhood_SWISU
# Neighborhood_Sawyer
# Neighborhood_SawyerW
# Neighborhood_Somerst
# Neighborhood_StoneBr
# Neighborhood_Timber
# Neighborhood_Veenker
# Condition 1_Artery
# Condition 1_Feedr
# Condition 1_Norm
# Condition 1_PosA
# Condition 1_PosN
# Condition 1_RRAe
# Condition 1_RRAn
# Condition 1_RRNe
# Condition 1_RRNn
# Condition 2_Artery
# Condition 2_Feedr
# Condition 2_Norm
# Condition 2_PosA
# Condition 2_PosN
# Condition 2_RRAe
# Condition 2_RRAn
# Condition 2_RRNn
# Bldg Type_1Fam
# Bldg Type_2fmCon
# Bldg Type_Duplex
# Bldg Type_Twnhs
# Bldg Type_TwnhsE
# House Style_1.5Fin
# House Style_1.5Unf
# House Style_1Story
# House Style_2.5Fin
# House Style_2.5Unf
# House Style_2Story
# House Style_SFoyer
# House Style_SLvl
# Roof Style_Flat
# Roof Style_Gable
# Roof Style_Gambrel
# Roof Style_Hip
# Roof Style_Mansard
# Roof Style_Shed
# Roof Matl_ClyTile
# Roof Matl_CompShg
# Roof Matl_Membran
# Roof Matl_Tar&Grv
# Roof Matl_WdShake
# Roof Matl_WdShngl
# Exterior 1st_AsbShng
# Exterior 1st_AsphShn
# Exterior 1st_BrkComm
# Exterior 1st_BrkFace
# Exterior 1st_CBlock
# Exterior 1st_CemntBd
# Exterior 1st_HdBoard
# Exterior 1st_ImStucc
# Exterior 1st_MetalSd
# Exterior 1st_Plywood
# Exterior 1st_Stone
# Exterior 1st_Stucco
# Exterior 1st_VinylSd
# Exterior 1st_Wd Sdng
# Exterior 1st_WdShing
# Exterior 2nd_AsbShng
# Exterior 2nd_AsphShn
# Exterior 2nd_Brk Cmn
# Exterior 2nd_BrkFace
# Exterior 2nd_CBlock
# Exterior 2nd_CmentBd
# Exterior 2nd_HdBoard
# Exterior 2nd_ImStucc
# Exterior 2nd_MetalSd
# Exterior 2nd_Plywood
# Exterior 2nd_Stone
# Exterior 2nd_Stucco
# Exterior 2nd_VinylSd
# Exterior 2nd_Wd Sdng
# Exterior 2nd_Wd Shng
# Foundation_BrkTil
# Foundation_CBlock
# Foundation_PConc
# Foundation_Slab
# Foundation_Stone
# Foundation_Wood
# Heating_GasA
# Heating_GasW
# Heating_Grav
# Heating_OthW
# Heating_Wall
# Central Air_N
# Central Air_Y
# Sale Type_COD
# Sale Type_CWD
# Sale Type_Con
# Sale Type_ConLD
# Sale Type_ConLI
# Sale Type_ConLw
# Sale Type_New
# Sale Type_Oth
# Sale Type_WD
# Alley_Grvl
# Alley_None
# Alley_Pave
# Mas Vnr Type_BrkCmn
# Mas Vnr Type_BrkFace
# Mas Vnr Type_None
# Mas Vnr Type_Stone
# Garage Type_2Types
# Garage Type_Attchd
# Garage Type_Basment
# Garage Type_BuiltIn
# Garage Type_CarPort
# Garage Type_Detchd
# Garage Type_None
# Misc Feature_Elev
# Misc Feature_Gar2
# Misc Feature_None
# Misc Feature_Othr
# Misc Feature_Shed
# Misc Feature_TenC

# %%
for i in test.columns:
    print(i)
# Out:
# Id
# PID
# Lot Frontage
# Lot Area
# Lot Shape
# Utilities
# Land Slope
# Overall Qual
# Overall Cond
# Year Built
# Year Remod/Add
# Mas Vnr Area
# Exter Qual
# Exter Cond
# Bsmt Qual
# Bsmt Cond
# Bsmt Exposure
# BsmtFin Type 1
# BsmtFin SF 1
# BsmtFin Type 2
# BsmtFin SF 2
# Bsmt Unf SF
# Total Bsmt SF
# Heating QC
# Electrical
# 1st Flr SF
# 2nd Flr SF
# Low Qual Fin SF
# Gr Liv Area
# Bsmt Full Bath
# Bsmt Half Bath
# Full Bath
# Half Bath
# Bedroom AbvGr
# Kitchen AbvGr
# Kitchen Qual
# TotRms AbvGrd
# Functional
# Fireplaces
# Fireplace Qu
# Garage Yr Blt
# Garage Finish
# Garage Cars
# Garage Area
# Garage Qual
# Garage Cond
# Paved Drive
# Wood Deck SF
# Open Porch SF
# Enclosed Porch
# 3Ssn Porch
# Screen Porch
# Pool Area
# Pool QC
# Fence
# Misc Val
# Mo Sold
# Yr Sold
# MS SubClass_20
# MS SubClass_30
# MS SubClass_40
# MS SubClass_45
# MS SubClass_50
# MS SubClass_60
# MS SubClass_70
# MS SubClass_75
# MS SubClass_80
# MS SubClass_85
# MS SubClass_90
# MS SubClass_120
# MS SubClass_160
# MS SubClass_180
# MS SubClass_190
# MS Zoning_C (all)
# MS Zoning_FV
# MS Zoning_I (all)
# MS Zoning_RH
# MS Zoning_RL
# MS Zoning_RM
# Street_Grvl
# Street_Pave
# Land Contour_Bnk
# Land Contour_HLS
# Land Contour_Low
# Land Contour_Lvl
# Lot Config_Corner
# Lot Config_CulDSac
# Lot Config_FR2
# Lot Config_FR3
# Lot Config_Inside
# Neighborhood_Blmngtn
# Neighborhood_Blueste
# Neighborhood_BrDale
# Neighborhood_BrkSide
# Neighborhood_ClearCr
# Neighborhood_CollgCr
# Neighborhood_Crawfor
# Neighborhood_Edwards
# Neighborhood_Gilbert
# Neighborhood_Greens
# Neighborhood_IDOTRR
# Neighborhood_MeadowV
# Neighborhood_Mitchel
# Neighborhood_NAmes
# Neighborhood_NPkVill
# Neighborhood_NWAmes
# Neighborhood_NoRidge
# Neighborhood_NridgHt
# Neighborhood_OldTown
# Neighborhood_SWISU
# Neighborhood_Sawyer
# Neighborhood_SawyerW
# Neighborhood_Somerst
# Neighborhood_StoneBr
# Neighborhood_Timber
# Neighborhood_Veenker
# Condition 1_Artery
# Condition 1_Feedr
# Condition 1_Norm
# Condition 1_PosA
# Condition 1_PosN
# Condition 1_RRAe
# Condition 1_RRAn
# Condition 1_RRNe
# Condition 1_RRNn
# Condition 2_Feedr
# Condition 2_Norm
# Condition 2_PosA
# Condition 2_PosN
# Bldg Type_1Fam
# Bldg Type_2fmCon
# Bldg Type_Duplex
# Bldg Type_Twnhs
# Bldg Type_TwnhsE
# House Style_1.5Fin
# House Style_1.5Unf
# House Style_1Story
# House Style_2.5Fin
# House Style_2.5Unf
# House Style_2Story
# House Style_SFoyer
# House Style_SLvl
# Roof Style_Flat
# Roof Style_Gable
# Roof Style_Gambrel
# Roof Style_Hip
# Roof Style_Mansard
# Roof Style_Shed
# Roof Matl_CompShg
# Roof Matl_Metal
# Roof Matl_Roll
# Roof Matl_Tar&Grv
# Roof Matl_WdShake
# Roof Matl_WdShngl
# Exterior 1st_AsbShng
# Exterior 1st_AsphShn
# Exterior 1st_BrkComm
# Exterior 1st_BrkFace
# Exterior 1st_CemntBd
# Exterior 1st_HdBoard
# Exterior 1st_MetalSd
# Exterior 1st_Plywood
# Exterior 1st_PreCast
# Exterior 1st_Stucco
# Exterior 1st_VinylSd
# Exterior 1st_Wd Sdng
# Exterior 1st_WdShing
# Exterior 2nd_AsbShng
# Exterior 2nd_AsphShn
# Exterior 2nd_Brk Cmn
# Exterior 2nd_BrkFace
# Exterior 2nd_CBlock
# Exterior 2nd_CmentBd
# Exterior 2nd_HdBoard
# Exterior 2nd_ImStucc
# Exterior 2nd_MetalSd
# Exterior 2nd_Other
# Exterior 2nd_Plywood
# Exterior 2nd_PreCast
# Exterior 2nd_Stucco
# Exterior 2nd_VinylSd
# Exterior 2nd_Wd Sdng
# Exterior 2nd_Wd Shng
# Foundation_BrkTil
# Foundation_CBlock
# Foundation_PConc
# Foundation_Slab
# Foundation_Stone
# Foundation_Wood
# Heating_Floor
# Heating_GasA
# Heating_GasW
# Heating_Grav
# Central Air_N
# Central Air_Y
# Sale Type_COD
# Sale Type_CWD
# Sale Type_Con
# Sale Type_ConLD
# Sale Type_ConLI
# Sale Type_ConLw
# Sale Type_New
# Sale Type_Oth
# Sale Type_VWD
# Sale Type_WD
# Alley_Grvl
# Alley_None
# Alley_Pave
# Mas Vnr Type_BrkCmn
# Mas Vnr Type_BrkFace
# Mas Vnr Type_CBlock
# Mas Vnr Type_None
# Mas Vnr Type_Stone
# Garage Type_2Types
# Garage Type_Attchd
# Garage Type_Basment
# Garage Type_BuiltIn
# Garage Type_CarPort
# Garage Type_Detchd
# Garage Type_None
# Misc Feature_Gar2
# Misc Feature_None
# Misc Feature_Othr
# Misc Feature_Shed

# %%
test.columns
# Out:
# Index(['Id', 'PID', 'Lot Frontage', 'Lot Area', 'Lot Shape', 'Utilities',
#        'Land Slope', 'Overall Qual', 'Overall Cond', 'Year Built',
#        ...
#        'Garage Type_Attchd', 'Garage Type_Basment', 'Garage Type_BuiltIn',
#        'Garage Type_CarPort', 'Garage Type_Detchd', 'Garage Type_None',
#        'Misc Feature_Gar2', 'Misc Feature_None', 'Misc Feature_Othr',
#        'Misc Feature_Shed'],
#       dtype='object', length=224)

# %%
#Check the difference in the train vs test set columns
train.columns.difference(test.columns)
# Out:
# Index(['Condition 2_Artery', 'Condition 2_RRAe', 'Condition 2_RRAn',
#        'Condition 2_RRNn', 'Exterior 1st_CBlock', 'Exterior 1st_ImStucc',
#        'Exterior 1st_Stone', 'Exterior 2nd_Stone', 'Heating_OthW',
#        'Heating_Wall', 'MS SubClass_150', 'MS Zoning_A (agr)',
#        'Misc Feature_Elev', 'Misc Feature_TenC', 'Neighborhood_GrnHill',
#        'Neighborhood_Landmrk', 'Roof Matl_ClyTile', 'Roof Matl_Membran',
#        'SalePrice'],
#       dtype='object')

# %%
#Drop all variables that do not appear in test set, excluding target variable 'SalePrice'
train.drop('Condition 2_Artery',axis=1,inplace=True)
train.drop('Condition 2_RRAe',axis=1,inplace=True)
train.drop('Condition 2_RRAn',axis=1,inplace=True)
train.drop('Condition 2_RRNn',axis=1,inplace=True)
train.drop('Exterior 1st_CBlock',axis=1,inplace=True)
train.drop('Exterior 1st_ImStucc',axis=1,inplace=True)
train.drop('Exterior 1st_Stone',axis=1,inplace=True)
train.drop('Exterior 2nd_Stone',axis=1,inplace=True)
train.drop('Heating_OthW',axis=1,inplace=True)
train.drop('Heating_Wall',axis=1,inplace=True)

train.drop('MS SubClass_150',axis=1,inplace=True)
train.drop('MS Zoning_A (agr)',axis=1,inplace=True)
train.drop('Misc Feature_Elev',axis=1,inplace=True)
train.drop('Misc Feature_TenC',axis=1,inplace=True)
train.drop('Neighborhood_GrnHill',axis=1,inplace=True)
train.drop('Neighborhood_Landmrk',axis=1,inplace=True)
train.drop('Roof Matl_ClyTile',axis=1,inplace=True)
train.drop('Roof Matl_Membran',axis=1,inplace=True)

# %%
#Check the difference in the test vs train set columns
test.columns.difference(train.columns)
# Out:
# Index(['Exterior 1st_PreCast', 'Exterior 2nd_Other', 'Exterior 2nd_PreCast',
#        'Heating_Floor', 'Mas Vnr Type_CBlock', 'Roof Matl_Metal',
#        'Roof Matl_Roll', 'Sale Type_VWD'],
#       dtype='object')

# %%
#Drop all variables that do not appear in train set, as the model won't be able to predict these variables
test.drop('Exterior 1st_PreCast',axis=1,inplace=True)
test.drop('Exterior 2nd_Other',axis=1,inplace=True)
test.drop('Exterior 2nd_PreCast',axis=1,inplace=True)
test.drop('Heating_Floor',axis=1,inplace=True)
test.drop('Mas Vnr Type_CBlock',axis=1,inplace=True)
test.drop('Roof Matl_Metal',axis=1,inplace=True)
test.drop('Roof Matl_Roll',axis=1,inplace=True)
test.drop('Sale Type_VWD',axis=1,inplace=True)

# %%
train.shape
# Out:
# (2045, 217)

# %%
test.shape
# Out:
# (879, 216)

# %%
#Comments on the data description revealed certain outliers that may skew the results of modelling
#A plot of Sale Price against general living area reveals 2 outliers that are above 4000 sq feet
sns.lmplot(x='SalePrice',y='Gr Liv Area',data=train)

# %%
#The details of the two outliers 
train[train['Gr Liv Area'] > 4000]
# Out:
#         Id        PID  Lot Frontage  Lot Area  Lot Shape  Utilities  \
# 960   1499  908154235         313.0     63887         -1          2
# 1885  2181  908154195         128.0     39290          1          2
#
#       Land Slope  Overall Qual  Overall Cond  Year Built  Year Remod/Add  \
# 960            0            10             5        2008            2008
# 1885           0            10             5        2008            2009
#
#       Mas Vnr Area  Exter Qual  Exter Cond  Bsmt Qual  Bsmt Cond  \
# 960          796.0           5           0          5          0
# 1885        1224.0           5           0          5          0
#
#       Bsmt Exposure  BsmtFin Type 1  BsmtFin SF 1  BsmtFin Type 2  \
# 960               5               5        5644.0              -2
# 1885              5               5        4010.0              -2
#
#       BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF  Heating QC  Electrical  \
# 960            0.0        466.0         6110.0           5           5
# 1885           0.0       1085.0         5095.0           5           5
#
#       1st Flr SF  2nd Flr SF  Low Qual Fin SF  Gr Liv Area  Bsmt Full Bath  \
# 960         4692         950                0         5642             2.0
# 1885        5095           0                0         5095             1.0
#
#       Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  Kitchen AbvGr  \
# 960              0.0          2          1              3              1
# 1885             1.0          2          1              2              1
#
#       Kitchen Qual  TotRms AbvGrd  Functional  Fireplaces  Fireplace Qu  \
# 960              5             12           3           3             2
# 1885             5             15           3           2             2
#
#       Garage Yr Blt  Garage Finish  Garage Cars  Garage Area  Garage Qual  \
# 960          2008.0              5          2.0       1418.0            0
# 1885         2008.0              5          3.0       1154.0            0
#
#       Garage Cond  Paved Drive  Wood Deck SF  Open Porch SF  Enclosed Porch  \
# 960             0            3           214            292               0
# 1885            0            3           546            484               0
#
#       3Ssn Porch  Screen Porch  Pool Area  Pool QC  Fence  Misc Val  Mo Sold  \
# 960            0             0        480        3     -3         0        1
# 1885           0             0          0        0     -3     17000       10
#
#       Yr Sold  SalePrice  MS SubClass_20  MS SubClass_30  MS SubClass_40  \
# 960      2008     160000               0               0               0
# 1885     2007     183850               1               0               0
#
#       MS SubClass_45  MS SubClass_50  MS SubClass_60  MS SubClass_70  \
# 960                0               0               1               0
# 1885               0               0               0               0
#
#       MS SubClass_75  MS SubClass_80  MS SubClass_85  MS SubClass_90  \
# 960                0               0               0               0
# 1885               0               0               0               0
#
#       MS SubClass_120  MS SubClass_160  MS SubClass_180  MS SubClass_190  \
# 960                 0                0                0                0
# 1885                0                0                0                0
#
#       MS Zoning_C (all)  MS Zoning_FV  MS Zoning_I (all)  MS Zoning_RH  \
# 960                   0             0                  0             0
# 1885                  0             0                  0             0
#
#       MS Zoning_RL  MS Zoning_RM  Street_Grvl  Street_Pave  Land Contour_Bnk  \
# 960              1             0            0            1                 1
# 1885             1             0            0            1                 1
#
#       Land Contour_HLS  Land Contour_Low  Land Contour_Lvl  Lot Config_Corner  \
# 960                  0                 0                 0                  1
# 1885                 0                 0                 0                  0
#
#       Lot Config_CulDSac  Lot Config_FR2  Lot Config_FR3  Lot Config_Inside  \
# 960                    0               0               0                  0
# 1885                   0               0               0                  1
#
#       Neighborhood_Blmngtn  Neighborhood_Blueste  Neighborhood_BrDale  \
# 960                      0                     0                    0
# 1885                     0                     0                    0
#
#       Neighborhood_BrkSide  Neighborhood_ClearCr  Neighborhood_CollgCr  \
# 960                      0                     0                     0
# 1885                     0                     0                     0
#
#       Neighborhood_Crawfor  Neighborhood_Edwards  Neighborhood_Gilbert  \
# 960                      0                     1                     0
# 1885                     0                     1                     0
#
#       Neighborhood_Greens  Neighborhood_IDOTRR  Neighborhood_MeadowV  \
# 960                     0                    0                     0
# 1885                    0                    0                     0
#
#       Neighborhood_Mitchel  Neighborhood_NAmes  Neighborhood_NPkVill  \
# 960                      0                   0                     0
# 1885                     0                   0                     0
#
#       Neighborhood_NWAmes  Neighborhood_NoRidge  Neighborhood_NridgHt  \
# 960                     0                     0                     0
# 1885                    0                     0                     0
#
#       Neighborhood_OldTown  Neighborhood_SWISU  Neighborhood_Sawyer  \
# 960                      0                   0                    0
# 1885                     0                   0                    0
#
#       Neighborhood_SawyerW  Neighborhood_Somerst  Neighborhood_StoneBr  \
# 960                      0                     0                     0
# 1885                     0                     0                     0
#
#       Neighborhood_Timber  Neighborhood_Veenker  Condition 1_Artery  \
# 960                     0                     0                   0
# 1885                    0                     0                   0
#
#       Condition 1_Feedr  Condition 1_Norm  Condition 1_PosA  Condition 1_PosN  \
# 960                   1                 0                 0                 0
# 1885                  0                 1                 0                 0
#
#       Condition 1_RRAe  Condition 1_RRAn  Condition 1_RRNe  Condition 1_RRNn  \
# 960                  0                 0                 0                 0
# 1885                 0                 0                 0                 0
#
#       Condition 2_Feedr  Condition 2_Norm  Condition 2_PosA  Condition 2_PosN  \
# 960                   0                 1                 0                 0
# 1885                  0                 1                 0                 0
#
#       Bldg Type_1Fam  Bldg Type_2fmCon  Bldg Type_Duplex  Bldg Type_Twnhs  \
# 960                1                 0                 0                0
# 1885               1                 0                 0                0
#
#       Bldg Type_TwnhsE  House Style_1.5Fin  House Style_1.5Unf  \
# 960                  0                   0                   0
# 1885                 0                   0                   0
#
#       House Style_1Story  House Style_2.5Fin  House Style_2.5Unf  \
# 960                    0                   0                   0
# 1885                   1                   0                   0
#
#       House Style_2Story  House Style_SFoyer  House Style_SLvl  \
# 960                    1                   0                 0
# 1885                   0                   0                 0
#
#       Roof Style_Flat  Roof Style_Gable  Roof Style_Gambrel  Roof Style_Hip  \
# 960                 0                 0                   0               1
# 1885                0                 0                   0               1
#
#       Roof Style_Mansard  Roof Style_Shed  Roof Matl_CompShg  \
# 960                    0                0                  0
# 1885                   0                0                  1
#
#       Roof Matl_Tar&Grv  Roof Matl_WdShake  Roof Matl_WdShngl  \
# 960                   0                  0                  0
# 1885                  0                  0                  0
#
#       Exterior 1st_AsbShng  Exterior 1st_AsphShn  Exterior 1st_BrkComm  \
# 960                      0                     0                     0
# 1885                     0                     0                     0
#
#       Exterior 1st_BrkFace  Exterior 1st_CemntBd  Exterior 1st_HdBoard  \
# 960                      0                     0                     0
# 1885                     0                     1                     0
#
#       Exterior 1st_MetalSd  Exterior 1st_Plywood  Exterior 1st_Stucco  \
# 960                      0                     0                    1
# 1885                     0                     0                    0
#
#       Exterior 1st_VinylSd  Exterior 1st_Wd Sdng  Exterior 1st_WdShing  \
# 960                      0                     0                     0
# 1885                     0                     0                     0
#
#       Exterior 2nd_AsbShng  Exterior 2nd_AsphShn  Exterior 2nd_Brk Cmn  \
# 960                      0                     0                     0
# 1885                     0                     0                     0
#
#       Exterior 2nd_BrkFace  Exterior 2nd_CBlock  Exterior 2nd_CmentBd  \
# 960                      0                    0                     0
# 1885                     0                    0                     1
#
#       Exterior 2nd_HdBoard  Exterior 2nd_ImStucc  Exterior 2nd_MetalSd  \
# 960                      0                     0                     0
# 1885                     0                     0                     0
#
#       Exterior 2nd_Plywood  Exterior 2nd_Stucco  Exterior 2nd_VinylSd  \
# 960                      0                    1                     0
# 1885                     0                    0                     0
#
#       Exterior 2nd_Wd Sdng  Exterior 2nd_Wd Shng  Foundation_BrkTil  \
# 960                      0                     0                  0
# 1885                     0                     0                  0
#
#       Foundation_CBlock  Foundation_PConc  Foundation_Slab  Foundation_Stone  \
# 960                   0                 1                0                 0
# 1885                  0                 1                0                 0
#
#       Foundation_Wood  Heating_GasA  Heating_GasW  Heating_Grav  \
# 960                 0             1             0             0
# 1885                0             1             0             0
#
#       Central Air_N  Central Air_Y  Sale Type_COD  Sale Type_CWD  \
# 960               0              1              0              0
# 1885              0              1              0              0
#
#       Sale Type_Con  Sale Type_ConLD  Sale Type_ConLI  Sale Type_ConLw  \
# 960               0                0                0                0
# 1885              0                0                0                0
#
#       Sale Type_New  Sale Type_Oth  Sale Type_WD   Alley_Grvl  Alley_None  \
# 960               1              0              0           0           1
# 1885              1              0              0           0           1
#
#       Alley_Pave  Mas Vnr Type_BrkCmn  Mas Vnr Type_BrkFace  \
# 960            0                    0                     0
# 1885           0                    0                     0
#
#       Mas Vnr Type_None  Mas Vnr Type_Stone  Garage Type_2Types  \
# 960                   0                   1                   0
# 1885                  0                   1                   0
#
#       Garage Type_Attchd  Garage Type_Basment  Garage Type_BuiltIn  \
# 960                    1                    0                    0
# 1885                   1                    0                    0
#
#       Garage Type_CarPort  Garage Type_Detchd  Garage Type_None  \
# 960                     0                   0                 0
# 1885                    0                   0                 0
#
#       Misc Feature_Gar2  Misc Feature_None  Misc Feature_Othr  \
# 960                   0                  1                  0
# 1885                  0                  0                  0
#
#       Misc Feature_Shed
# 960                   0
# 1885                  0

# %%
test[test['Gr Liv Area']>4000]
# Out:
#        Id        PID  Lot Frontage  Lot Area  Lot Shape  Utilities  \
# 76   2182  908154205         130.0     40094          1          2
# 171  1761  528320050         160.0     15623          1          2
# 464  1768  528351010         104.0     21535          1          2
#
#      Land Slope  Overall Qual  Overall Cond  Year Built  Year Remod/Add  \
# 76            0            10             5        2007            2008
# 171           0            10             5        1996            1996
# 464           0            10             6        1994            1995
#
#      Mas Vnr Area  Exter Qual  Exter Cond  Bsmt Qual  Bsmt Cond  \
# 76          762.0           5           0          5          0
# 171           0.0           2           0          5          0
# 464        1170.0           5           0          5          0
#
#      Bsmt Exposure  BsmtFin Type 1  BsmtFin SF 1  BsmtFin Type 2  \
# 76               5               5          2260              -2
# 171              2               5          2096              -2
# 464              5               5          1455              -2
#
#      BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF  Heating QC  Electrical  \
# 76              0          878           3138           5           5
# 171             0          300           2396           5           5
# 464             0          989           2444           5           5
#
#      1st Flr SF  2nd Flr SF  Low Qual Fin SF  Gr Liv Area  Bsmt Full Bath  \
# 76         3138        1538                0         4676               1
# 171        2411        2065                0         4476               1
# 464        2444        1872                0         4316               0
#
#      Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  Kitchen AbvGr  \
# 76                0          3          1              3              1
# 171               0          3          1              4              1
# 464               1          3          1              4              1
#
#      Kitchen Qual  TotRms AbvGrd  Functional  Fireplaces  Fireplace Qu  \
# 76              5             11           3           1             2
# 171             5             10           3           2             0
# 464             5             10           3           2             5
#
#      Garage Yr Blt  Garage Finish  Garage Cars  Garage Area  Garage Qual  \
# 76          2007.0              5            3          884            0
# 171         1996.0              5            3          813            0
# 464         1994.0              5            3          832            0
#
#      Garage Cond  Paved Drive  Wood Deck SF  Open Porch SF  Enclosed Porch  \
# 76             0            3           208            406               0
# 171            0            3           171             78               0
# 464            0            3           382             50               0
#
#      3Ssn Porch  Screen Porch  Pool Area  Pool QC  Fence  Misc Val  Mo Sold  \
# 76            0             0          0        0     -3         0       10
# 171           0             0        555        6      2         0        7
# 464           0             0          0        0     -3         0        1
#
#      Yr Sold  MS SubClass_20  MS SubClass_30  MS SubClass_40  MS SubClass_45  \
# 76      2007               0               0               0               0
# 171     2007               0               0               0               0
# 464     2007               0               0               0               0
#
#      MS SubClass_50  MS SubClass_60  MS SubClass_70  MS SubClass_75  \
# 76                0               1               0               0
# 171               0               1               0               0
# 464               0               1               0               0
#
#      MS SubClass_80  MS SubClass_85  MS SubClass_90  MS SubClass_120  \
# 76                0               0               0                0
# 171               0               0               0                0
# 464               0               0               0                0
#
#      MS SubClass_160  MS SubClass_180  MS SubClass_190  MS Zoning_C (all)  \
# 76                 0                0                0                  0
# 171                0                0                0                  0
# 464                0                0                0                  0
#
#      MS Zoning_FV  MS Zoning_I (all)  MS Zoning_RH  MS Zoning_RL  \
# 76              0                  0             0             1
# 171             0                  0             0             1
# 464             0                  0             0             1
#
#      MS Zoning_RM  Street_Grvl  Street_Pave  Land Contour_Bnk  \
# 76              0            0            1                 1
# 171             0            0            1                 0
# 464             0            0            1                 0
#
#      Land Contour_HLS  Land Contour_Low  Land Contour_Lvl  Lot Config_Corner  \
# 76                  0                 0                 0                  0
# 171                 0                 0                 1                  1
# 464                 0                 0                 1                  1
#
#      Lot Config_CulDSac  Lot Config_FR2  Lot Config_FR3  Lot Config_Inside  \
# 76                    0               0               0                  1
# 171                   0               0               0                  0
# 464                   0               0               0                  0
#
#      Neighborhood_Blmngtn  Neighborhood_Blueste  Neighborhood_BrDale  \
# 76                      0                     0                    0
# 171                     0                     0                    0
# 464                     0                     0                    0
#
#      Neighborhood_BrkSide  Neighborhood_ClearCr  Neighborhood_CollgCr  \
# 76                      0                     0                     0
# 171                     0                     0                     0
# 464                     0                     0                     0
#
#      Neighborhood_Crawfor  Neighborhood_Edwards  Neighborhood_Gilbert  \
# 76                      0                     1                     0
# 171                     0                     0                     0
# 464                     0                     0                     0
#
#      Neighborhood_Greens  Neighborhood_IDOTRR  Neighborhood_MeadowV  \
# 76                     0                    0                     0
# 171                    0                    0                     0
# 464                    0                    0                     0
#
#      Neighborhood_Mitchel  Neighborhood_NAmes  Neighborhood_NPkVill  \
# 76                      0                   0                     0
# 171                     0                   0                     0
# 464                     0                   0                     0
#
#      Neighborhood_NWAmes  Neighborhood_NoRidge  Neighborhood_NridgHt  \
# 76                     0                     0                     0
# 171                    0                     1                     0
# 464                    0                     1                     0
#
#      Neighborhood_OldTown  Neighborhood_SWISU  Neighborhood_Sawyer  \
# 76                      0                   0                    0
# 171                     0                   0                    0
# 464                     0                   0                    0
#
#      Neighborhood_SawyerW  Neighborhood_Somerst  Neighborhood_StoneBr  \
# 76                      0                     0                     0
# 171                     0                     0                     0
# 464                     0                     0                     0
#
#      Neighborhood_Timber  Neighborhood_Veenker  Condition 1_Artery  \
# 76                     0                     0                   0
# 171                    0                     0                   0
# 464                    0                     0                   0
#
#      Condition 1_Feedr  Condition 1_Norm  Condition 1_PosA  Condition 1_PosN  \
# 76                   0                 0                 0                 1
# 171                  0                 1                 0                 0
# 464                  0                 1                 0                 0
#
#      Condition 1_RRAe  Condition 1_RRAn  Condition 1_RRNe  Condition 1_RRNn  \
# 76                  0                 0                 0                 0
# 171                 0                 0                 0                 0
# 464                 0                 0                 0                 0
#
#      Condition 2_Feedr  Condition 2_Norm  Condition 2_PosA  Condition 2_PosN  \
# 76                   0                 0                 0                 1
# 171                  0                 1                 0                 0
# 464                  0                 1                 0                 0
#
#      Bldg Type_1Fam  Bldg Type_2fmCon  Bldg Type_Duplex  Bldg Type_Twnhs  \
# 76                1                 0                 0                0
# 171               1                 0                 0                0
# 464               1                 0                 0                0
#
#      Bldg Type_TwnhsE  House Style_1.5Fin  House Style_1.5Unf  \
# 76                  0                   0                   0
# 171                 0                   0                   0
# 464                 0                   0                   0
#
#      House Style_1Story  House Style_2.5Fin  House Style_2.5Unf  \
# 76                    0                   0                   0
# 171                   0                   0                   0
# 464                   0                   0                   0
#
#      House Style_2Story  House Style_SFoyer  House Style_SLvl  \
# 76                    1                   0                 0
# 171                   1                   0                 0
# 464                   1                   0                 0
#
#      Roof Style_Flat  Roof Style_Gable  Roof Style_Gambrel  Roof Style_Hip  \
# 76                 0                 0                   0               1
# 171                0                 0                   0               1
# 464                0                 1                   0               0
#
#      Roof Style_Mansard  Roof Style_Shed  Roof Matl_CompShg  \
# 76                    0                0                  1
# 171                   0                0                  1
# 464                   0                0                  0
#
#      Roof Matl_Tar&Grv  Roof Matl_WdShake  Roof Matl_WdShngl  \
# 76                   0                  0                  0
# 171                  0                  0                  0
# 464                  0                  0                  1
#
#      Exterior 1st_AsbShng  Exterior 1st_AsphShn  Exterior 1st_BrkComm  \
# 76                      0                     0                     0
# 171                     0                     0                     0
# 464                     0                     0                     0
#
#      Exterior 1st_BrkFace  Exterior 1st_CemntBd  Exterior 1st_HdBoard  \
# 76                      0                     1                     0
# 171                     0                     0                     0
# 464                     0                     0                     1
#
#      Exterior 1st_MetalSd  Exterior 1st_Plywood  Exterior 1st_Stucco  \
# 76                      0                     0                    0
# 171                     0                     0                    0
# 464                     0                     0                    0
#
#      Exterior 1st_VinylSd  Exterior 1st_Wd Sdng  Exterior 1st_WdShing  \
# 76                      0                     0                     0
# 171                     0                     1                     0
# 464                     0                     0                     0
#
#      Exterior 2nd_AsbShng  Exterior 2nd_AsphShn  Exterior 2nd_Brk Cmn  \
# 76                      0                     0                     0
# 171                     0                     0                     0
# 464                     0                     0                     0
#
#      Exterior 2nd_BrkFace  Exterior 2nd_CBlock  Exterior 2nd_CmentBd  \
# 76                      0                    0                     1
# 171                     0                    0                     0
# 464                     0                    0                     0
#
#      Exterior 2nd_HdBoard  Exterior 2nd_ImStucc  Exterior 2nd_MetalSd  \
# 76                      0                     0                     0
# 171                     0                     1                     0
# 464                     1                     0                     0
#
#      Exterior 2nd_Plywood  Exterior 2nd_Stucco  Exterior 2nd_VinylSd  \
# 76                      0                    0                     0
# 171                     0                    0                     0
# 464                     0                    0                     0
#
#      Exterior 2nd_Wd Sdng  Exterior 2nd_Wd Shng  Foundation_BrkTil  \
# 76                      0                     0                  0
# 171                     0                     0                  0
# 464                     0                     0                  0
#
#      Foundation_CBlock  Foundation_PConc  Foundation_Slab  Foundation_Stone  \
# 76                   0                 1                0                 0
# 171                  0                 1                0                 0
# 464                  0                 1                0                 0
#
#      Foundation_Wood  Heating_GasA  Heating_GasW  Heating_Grav  Central Air_N  \
# 76                 0             1             0             0              0
# 171                0             1             0             0              0
# 464                0             1             0             0              0
#
#      Central Air_Y  Sale Type_COD  Sale Type_CWD  Sale Type_Con  \
# 76               1              0              0              0
# 171              1              0              0              0
# 464              1              0              0              0
#
#      Sale Type_ConLD  Sale Type_ConLI  Sale Type_ConLw  Sale Type_New  \
# 76                 0                0                0              1
# 171                0                0                0              0
# 464                0                0                0              0
#
#      Sale Type_Oth  Sale Type_WD   Alley_Grvl  Alley_None  Alley_Pave  \
# 76               0              0           0           1           0
# 171              0              1           0           1           0
# 464              0              1           0           1           0
#
#      Mas Vnr Type_BrkCmn  Mas Vnr Type_BrkFace  Mas Vnr Type_None  \
# 76                     0                     0                  0
# 171                    0                     0                  1
# 464                    0                     1                  0
#
#      Mas Vnr Type_Stone  Garage Type_2Types  Garage Type_Attchd  \
# 76                    1                   0                   0
# 171                   0                   0                   1
# 464                   0                   0                   1
#
#      Garage Type_Basment  Garage Type_BuiltIn  Garage Type_CarPort  \
# 76                     0                    1                    0
# 171                    0                    0                    0
# 464                    0                    0                    0
#
#      Garage Type_Detchd  Garage Type_None  Misc Feature_Gar2  \
# 76                    0                 0                  0
# 171                   0                 0                  0
# 464                   0                 0                  0
#
#      Misc Feature_None  Misc Feature_Othr  Misc Feature_Shed
# 76                   1                  0                  0
# 171                  1                  0                  0
# 464                  1                  0                  0

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2045 entries, 0 to 2050
# Columns: 217 entries, Id to Misc Feature_Shed
# dtypes: float64(11), int64(48), uint8(158)
# memory usage: 1.2 MB

# %%
#save the cleaned file into a new csv file 
train.to_csv('../datasets/train_clean.csv')
test.to_csv('../datasets/test_clean.csv')
